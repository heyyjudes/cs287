# %% [markdown]
# # HW 2: Language Modeling

# %% [markdown]
# In this homework you will be building several varieties of language models.
#
# ## Goal
#
# We ask that you construct the following models in PyTorch:
#
# 1. A trigram model with linear-interpolation. $$p(y_t | y_{1:t-1}) =  \alpha_1 p(y_t | y_{t-2}, y_{t-1}) + \alpha_2 p(y_t | y_{t-1}) + (1 - \alpha_1 - \alpha_2) p(y_t) $$
# 2. A neural network language model (consult *A Neural Probabilistic Language Model* http://www.jmlr.org/papers/volume3/bengio03a/bengio03a.pdf)
# 3. An LSTM language model (consult *Recurrent Neural Network Regularization*, https://arxiv.org/pdf/1409.2329.pdf)
# 4. Your own extensions to these models...
#
#
# Consult the papers provided for hyperparameters.

# %% [markdown]
# ## Setup
#
# This notebook provides a working definition of the setup of the problem itself. You may construct your models inline or use an external setup (preferred) to build your system.

# %%
# Text text processing library
import torchtext
from torchtext.vocab import Vectors

# %% [markdown]
# The dataset we will use of this problem is known as the Penn Treebank (http://aclweb.org/anthology/J93-2004). It is the most famous dataset in NLP and includes a large set of different types of annotations. We will be using it here in a simple case as just a language modeling dataset.

# %% [markdown]
# To start, `torchtext` requires that we define a mapping from the raw text data to featurized indices. These fields make it easy to map back and forth between readable data and math, which helps for debugging.

# %%
# Our input $x$
TEXT = torchtext.data.Field()

# %% [markdown]
# Next we input our data. Here we will use the first 10k sentences of the standard PTB language modeling split, and tell it the fields.

# %%
# Data distributed with the assignment
train, val, test = torchtext.datasets.LanguageModelingDataset.splits(
    path=".", 
    train="train.txt", validation="valid.txt", test="valid.txt", text_field=TEXT)

# %% [markdown]
# The data format for language modeling is strange. We pretend the entire corpus is one long sentence.

# %%
print('len(train)', len(train))

# %% [markdown]
# Here's the vocab itself. (This dataset has unk symbols already, but torchtext adds its own.)

# %%
TEXT.build_vocab(train)
print('len(TEXT.vocab)', len(TEXT.vocab))

# %% [markdown]
# When debugging you may want to use a smaller vocab size. This will run much faster.

# %%
if False:
    TEXT.build_vocab(train, max_size=1000)
    len(TEXT.vocab)

# %% [markdown]
# The batching is done in a strange way for language modeling. Each element of the batch consists of `bptt_len` words in order. This makes it easy to run recurrent models like RNNs.

# %%
train_iter, val_iter, test_iter = torchtext.data.BPTTIterator.splits(
    (train, val, test), batch_size=10, device=-1, bptt_len=32, repeat=False)

# %% [markdown]
# Here's what these batches look like. Each is a string of length 32. Sentences are ended with a special `<eos>` token.

# %%
it = iter(train_iter)
batch = next(it) 
print(vars(batch))
print("Size of text batch [max bptt length, batch size]", batch.text.size())
print("Second in batch", batch.text[:, 2])
print("Converted back to string: ", " ".join([TEXT.vocab.itos[i] for i in batch.text[:, 2].data]))

# %% [markdown]
# The next batch will be the continuation of the previous. This is helpful for running recurrent neural networks where you remember the current state when transitioning.

# %%
batch = next(it)
print("Converted back to string: ", " ".join([TEXT.vocab.itos[i] for i in batch.text[:, 2].data]))
print("Converted back to string: ", " ".join([TEXT.vocab.itos[i] for i in batch.text[:, 3].data]))
print("Converted back to string: ", " ".join([TEXT.vocab.itos[i] for i in batch.text[:, 4].data]))

# %% [markdown]
# There are no separate labels. But you can just use an offset `batch.text[1:]` to get the next word.

# %% [markdown]
# ## Assignment
#
# Now it is your turn to build the models described at the top of the assignment.
#
# Using the data given by this iterator, you should construct 3 different torch models that take in batch.text and produce a distribution over the next word.
#
# When a model is trained, use the following test function to produce predictions, and then upload to the kaggle competition: https://www.kaggle.com/c/cs287-hw2-s18

# %% [markdown]
# For the final Kaggle test, we will have you do a next word prediction task. We will provide a 10 word prefix of sentences, and it is your job to predict 10 possible next word candidates

# %%
# !head input.txt

# %% [markdown]
# As a sample Kaggle submission, let us build a simple unigram model.

# %%
from collections import Counter
count = Counter()
for b in iter(train_iter):
    count.update(b.text.view(-1).data.tolist())
count[TEXT.vocab.stoi["<eos>"]] = 0
predictions = [TEXT.vocab.itos[i] for i, c in count.most_common(20)]
print(predictions)
with open("sample.txt", "w") as fout: 
    print("id,word", file=fout)
    for i, l in enumerate(open("input.txt"), 1):
        print("%d,%s"%(i, " ".join(predictions)), file=fout)

# %%
# !head sample.txt

# %% [markdown]
# The metric we are using is mean average precision of your 20-best list.
#
# $$MAP@20 = \frac{1}{|D|} \sum_{u=1}^{|D|} \sum_{k=1}^{20} Precision(u, 1:k)$$
#
# Ideally we would use log-likelihood or ppl as discussed in class, but this is the best Kaggle gives us. This takes into account whether you got the right answer and how highly you ranked it.
#
# In particular, we ask that you do not game this metric. Please submit *exactly 20* unique predictions for each example.

# %% [markdown]
# As always you should put up a 5-6 page write-up following the template provided in the repository:  https://github.com/harvard-ml-courses/cs287-s18/blob/master/template/

# %% [markdown]
# # Neural Probabalistic Language Model

# %%
# Text text processing library
import torchtext
import torch
import math 
import torch.nn as nn 
from torchtext.vocab import Vectors
DEBUG = True 
# Our input $x$
TEXT = torchtext.data.Field()
# Data distributed with the assignment
train, val, test = torchtext.datasets.LanguageModelingDataset.splits(
    path=".", 
    train="train.txt", validation="valid.txt", test="valid.txt", text_field=TEXT)
TEXT.build_vocab(train)
print('len(TEXT.vocab)', len(TEXT.vocab))

if DEBUG == True:
    TEXT.build_vocab(train, max_size=1000)
    len(TEXT.vocab)
    print('len(TEXT.vocab)', len(TEXT.vocab))
    
train_iter, val_iter, test_iter = torchtext.data.BPTTIterator.splits(
    (train, val, test), batch_size=12, device=-1, bptt_len=32, repeat=False, shuffle=False)
# Out:
# len(TEXT.vocab) 10001
# len(TEXT.vocab) 1002

# %%
class NPLM(nn.Module):
    def __init__(self, V_vocab_dim, M_embed_dim, H_hidden_dim, N_seq_len):
        super(NPLM, self).__init__()
        self.vocab_size = V_vocab_dim
        self.embed = nn.Embedding(V_vocab_dim, M_embed_dim)
        self.hidden_linear = nn.Linear(M_embed_dim*N_seq_len, H_hidden_dim, bias=True)
        self.tanh_act = nn.Tanh()
        self.U_linear = nn.Linear(H_hidden_dim, V_vocab_dim, bias=True)
        self.W_linear = nn.Linear(M_embed_dim*N_seq_len, V_vocab_dim, bias=True)
        self.softmax = nn.LogSoftmax()

    def forward(self, x):
        x_embed = self.embed(x)
        x_flat = torch.autograd.Variable(torch.cat(x_embed.data, dim=1))
        hidden_feat = self.hidden_linear(x_flat)
        hidden_act = self.tanh_act(hidden_feat)
        hidden_out = self.U_linear(hidden_act)
        direct = self.W_linear(x_flat)
        out = direct + hidden_out
        return self.softmax(out)

# %%
def evaluate(model, data_iterator):
    # Turn on evaluation mode which disables dropout.
    #model.eval()
    total_loss = 0
    batch_count = 0
    for batch in iter(data_iterator):
        batch_loss = 0
        N_tokens = batch.text.size(0) - 4
        for i in range(N_tokens):
            output = model(batch.text[i:i+4])
            target = batch.text[i+4]
            batch_loss += criterion(output, target).data[0]
        total_loss += batch_loss/N_tokens
        batch_count += 1
    return total_loss / batch_count

def train_batch(model, criterion, optim, batch, label):
    # initialize hidden vectors
    model.zero_grad()
    # calculate forward pass
    y = model(batch)
    # calculate loss
    loss = criterion(y, label)
    # backpropagate and step
    loss.backward()
    optim.step()
    return loss.data[0]

# training loop
def run_training(model, criterion, optim, data_iterator):

    for e in range(n_epochs):
        batches = 0
        epoch_loss = 0
        for batch in iter(data_iterator):
            batch_loss = 0
            N_tokens = batch.text.size(0) - 4
            for i in range(N_tokens):
                batch_loss += train_batch(model, criterion, optim, batch.text[i:i+4], batch.text[i+4])
            batches += 1
            epoch_loss += batch_loss/N_tokens
        epoch_loss /= batches
        print("Epoch ", e, " Loss: ", epoch_loss, "Perplexity: ", math.exp(epoch_loss))
        train_loss = evaluate(model, data_iterator)
        print("Epoch Train Loss: ", train_loss, "Perplexity: ", math.exp(train_loss))
        val_loss = evaluate(model, val_iter)
        print("Epoch Val Loss: ", val_loss, "Perplexity: ", math.exp(val_loss))
        torch.save(npl.state_dict(), 'npl_full_model.pt')

# %%
# size of the embeddings and vectors
n_embedding = 30
n_hidden = 100
seq_len = 4
n_epochs = 10
learning_rate = .1
weight_decay = 0

npl = NPLM(len(TEXT.vocab), n_embedding, n_hidden, seq_len)
criterion = nn.NLLLoss()
optim = torch.optim.SGD(npl.parameters(), lr=learning_rate, weight_decay=weight_decay)

run_training(npl, criterion, optim, train_iter)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: generator 'BPTTIterator.__iter__' raised StopIteration
# Epoch  0  Loss:  4.2661785848759735 Perplexity:  71.24884331745294
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: generator 'BPTTIterator.__iter__' raised StopIteration
# Epoch Train Loss:  4.1354655157986 Perplexity:  62.51868773430979
# Epoch Val Loss:  4.244445357805354 Perplexity:  69.71708138343561
# Epoch  1  Loss:  4.105593250865666 Perplexity:  60.67873158191939
# Epoch Train Loss:  4.0666462902115 Perplexity:  58.360908471332415
# Epoch Val Loss:  4.207913405316392 Perplexity:  67.21614054136651
# Epoch  2  Loss:  4.059195415375193 Perplexity:  57.92768459962089
# Epoch Train Loss:  4.039158546874889 Perplexity:  56.778546213842596
# Epoch Val Loss:  4.200333999228601 Perplexity:  66.70860794407817
# Epoch  3  Loss:  4.0322333836226765 Perplexity:  56.38670386420162
# Epoch Train Loss:  4.023240508314374 Perplexity:  55.88189849521274
# Epoch Val Loss:  4.200041637254768 Perplexity:  66.68910773448677
# Epoch  4  Loss:  4.014770594938606 Perplexity:  55.41058247626998
# Epoch Train Loss:  4.007050063105906 Perplexity:  54.984430487179715
# Epoch Val Loss:  4.196109267317041 Perplexity:  66.42737644146621
# Epoch  5  Loss:  4.001994693432386 Perplexity:  54.70716529430267
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-707a5da4d8fa> in <module>()
#      11 optim = torch.optim.SGD(npl.parameters(), lr=learning_rate, weight_decay=weight_decay)
#      12
# ---> 13 run_training(npl, criterion, optim, train_iter)
#
# <ipython-input-6-723cbf1cdd16> in run_training(model, criterion, optim, data_iterator)
#      42         epoch_loss /= batches
#      43         print("Epoch ", e, " Loss: ", epoch_loss, "Perplexity: ", math.exp(epoch_loss))
# ---> 44         train_loss = evaluate(model, data_iterator)
#      45         print("Epoch Train Loss: ", train_loss, "Perplexity: ", math.exp(train_loss))
#      46         val_loss = evaluate(model, val_iter)
#
# <ipython-input-6-723cbf1cdd16> in evaluate(model, data_iterator)
#       8         N_tokens = batch.text.size(0) - 4
#       9         for i in range(N_tokens):
# ---> 10             output = model(batch.text[i:i+4])
#      11             target = batch.text[i+4]
#      12             batch_loss += criterion(output, target).data[0]
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     323         for hook in self._forward_pre_hooks.values():
#     324             hook(self, input)
# --> 325         result = self.forward(*input, **kwargs)
#     326         for hook in self._forward_hooks.values():
#     327             hook_result = hook(self, input, result)
#
# <ipython-input-5-5a45352c26a0> in forward(self, x)
#      18         #print(hidden_feat)
#      19         hidden_act = self.tanh_act(hidden_feat)
# ---> 20         hidden_out = self.U_linear(hidden_act)
#      21         direct = self.W_linear(x_flat)
#      22         out = direct + hidden_out
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     323         for hook in self._forward_pre_hooks.values():
#     324             hook(self, input)
# --> 325         result = self.forward(*input, **kwargs)
#     326         for hook in self._forward_hooks.values():
#     327             hook_result = hook(self, input, result)
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def __repr__(self):
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     833     if input.dim() == 2 and bias is not None:
#     834         # fused op is marginally faster
# --> 835         return torch.addmm(bias, input, weight.t())
#     836
#     837     output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
with open("sample.txt", "w") as fout: 
    print("id,word", file=fout)
    for i, l in enumerate(open("input.txt"), 1):
        print(l)
        input_tokens = l.split(" ")[-5:-1]
        input_index = torch.LongTensor([TEXT.vocab.stoi[t] for t in input_tokens]).unsqueeze(1)
        output = npl(torch.autograd.Variable(input_index))
        max_values, max_indices = torch.topk(output, 20)
        print(" ".join([TEXT.vocab.itos[int(i)] for i in max_indices.data[0, :]]))
        
        #print("%d,%s"%(i, " ".join(predictions)), file=fout)
# Out:
# but while the new york stock exchange did n't fall ___
#
# <eos> on <unk> and closed face for out said a that had as about of will much set to were
# some circuit breakers installed after the october N crash failed ___
#
# to rates rate N <unk> by the shares 's at or and business with for as this stock which european
# the N stock specialist firms on the big board floor ___
#
# the <unk> in as a <eos> its to N and $ are his 's an that of about do at
# big investment banks refused to step up to the plate ___
#
# <eos> <unk> of for law and in N to has the 's are or stock was year public with trade
# heavy selling of standard & poor 's 500-stock index futures ___
#
# contract a markets <unk> the for <eos> programs prices terms off problems in $ and no were news some has
# seven big board stocks ual amr bankamerica walt disney capital ___
#
# <eos> markets <unk> at for management by gains inc. in and a as corp. to which the losses is co.
# once again the specialists were not able to handle the ___
#
# <unk> first new federal future N growth product most test market european way exchange second center the proposed cost two
# <unk> james <unk> chairman of specialists henderson brothers inc. it ___
#
# is acquired <unk> had has would said filed was seems did <eos> received 's also sold may plans the expects
# when the dollar is in a <unk> even central banks ___
#
# <unk> by in a and <eos> at to of for that corp inc. were have investors we which is the
# speculators are calling for a degree of liquidity that is ___
#
# <unk> n't a not the likely less expected in still seeking an being no also for that now it held
# many money managers and some traders had already left their ___
#
# <unk> own work said assets market $ money securities bill big <eos> name magazine interest average 's share bonds and
# then in a <unk> plunge the dow jones industrials in ___
#
# <unk> the a august its N several los other this new south california which federal full government his their future
# <unk> trading accelerated to N million shares a record for ___
#
# a <unk> two the $ some about an N all its future other ual each mr. example whether one advanced
# at the end of the day N million shares were ___
#
# <unk> $ n't closed said about N mortgage common <eos> all up at higher little only related the less in
# the dow 's decline was second in point terms only ___
#
# <unk> a in N the if investors two stocks $ about <eos> one 's people u.s. today have year days
# in percentage terms however the dow 's dive was the ___
#
# <unk> first the oct. most test short following loan state report second u.s. high N last next top company shares
# shares of ual the parent of united airlines were extremely ___
#
# <eos> <unk> the 's in and by to that of its back about management for have it as prices which
# wall street 's takeover-stock speculators or risk arbitragers had placed ___
#
# the <eos> for of an and by management a as or <unk> with loan about to in said $ 's
# at N p.m. edt came the <unk> news the big ___
#
# board <unk> <eos> does group of for it $ the market a financial industry often is would possible other to
# on the exchange floor as soon as ual stopped trading ___
#
# <unk> <eos> the N to its volume by a as and at for this on unit yesterday commission which will
# several traders could be seen shaking their heads when the ___
#
# <unk> government company new big s&p recent problems power capital u.s. dollar federal market world program tokyo exchange food offer
# for weeks the market had been nervous about takeovers after ___
#
# the <unk> a of this his it taxes five seeking for its south they european large losses and is mr.
# and N minutes after the ual trading halt came news ___
#
# of <unk> in the and <eos> for as 's to corp agency markets that by south reports it companies market
# arbitragers could n't dump their ual stock but they rid ___
#
# in <unk> as a for the <eos> and 's of about by N that made under to said on with
# for example their selling caused trading halts to be declared ___
#
# by <eos> for to the <unk> 's and as in at a but after into has its between said during
# but as panic spread speculators began to sell blue-chip stocks ___
#
# <unk> than to said in <eos> of and despite 's at tax including into on with but since have capital
# when trading was halted in philip morris the stock was ___
#
# a <unk> $ <eos> n't found up no closed not the priced made an this about N named doing that
# selling <unk> because of waves of automatic stop-loss orders which ___
#
# has is a had are would the owns <eos> 's <unk> was includes for an it can could makes often
# most of the stock selling pressure came from wall street ___
#
# journal firms said the <eos> corp. which <unk> is a and index analysts trading was has inc. maker account of
# traders said most of their major institutional investors on the ___
#
# <unk> chicago new subject sale big street company $ N issue test percentage recent unit name world federal board open
# now at N one of the market 's post-crash reforms ___
#
# <eos> the to and <unk> by co. 's unit for co brothers of has plant on management as with it
# under an agreement signed by the big board and the ___
#
# <unk> recent company new dollar department growth stock big chicago shares government sale exchange biggest general dow trading current board
# after the trading halt in the s&p N pit in ___
#
# <unk> the a august los this california new which july cash shares N each growth federal its government several notes
# as a result the link between the futures and stock ___
#
# exchange to <unk> market of for prices in markets on as and would was other has with <eos> at are
# without the <unk> of stock-index futures the barometer of where ___
#
# the it <unk> interest at they mr. of business <eos> an there we $ that in three funds i a
# the futures halt was even <unk> by big board floor ___
#
# <unk> a the as <eos> to its do and N in 's of that this $ off about his so
# this confusion effectively halted one form of program trading stock ___
#
# to market <unk> prices for and at exchange in holdings <eos> $ N has of because but said it the
# in a stock-index arbitrage sell program traders buy or sell ___
#
# the a <eos> $ it <unk> that an both its programs your or all big large in their when for
# when the airline information came through it <unk> every model ___
#
# the for <eos> a an of with to that as its and are $ in said 's under by it
# we did n't even get a chance to do the ___
#
# <unk> same first federal plan public most $ test treasury volume biggest company N new second program number dollar following
# the dow industrials were down N points at N p.m. ___
#
# 's <eos> in of and that yen a on for the <unk> as with are by its to from said
# at N p.m. at the end of the cooling off ___
#
# a <eos> the <unk> to which in for at by its of it N capital that said is on industry
# meanwhile during the the s&p trading halt s&p futures sell ___
#
# a $ <unk> the orders its traded an <eos> assets for at large or by all when that and included
# big board chairman john j. phelan said yesterday the circuit ___
#
# <eos> of <unk> or for and industry with the will agreement are ' which 's computer by law banking has
# i just think it 's <unk> at this point to ___
#
# <unk> be the a see purchase N provide $ make give meet those buy do yield pay take some face
# under another post-crash system big board president richard <unk> mr. ___
#
# <unk> inc. the price court bush unit plc quarter inc face co. venture business on jones tax corp. good executive
# he <unk> out at a high-tech <unk> center on the ___
#
# <unk> new issue common close N recent market dollar sale day $ subject same big first leading best treasury federal
# at about N p.m. edt s&p futures resumed trading and ___
#
# <unk> the a to by other an in related it construction that not $ is N japan mr. no one
# but the <unk> of s&p futures sell orders weighed on ___
#
# <unk> the a oct. this its tuesday whether to new their business by domestic stock it companies sales such treasury
# at about N the s&p market <unk> to still another ___
#
# <unk> a to at $ <eos> rates by about but wednesday for and the lower points N demand monday from
# futures traders say the s&p was <unk> that the dow ___
#
# jones <unk> a was concern of <eos> is could interest has price 's agency system board filed u.s. did chief
# during this time small investors began ringing their brokers wondering ___
#
# <eos> for <unk> and by of a in that 's losses it said the securities brothers which operations or on
# at prudential-bache securities inc. which is trying to cater to ___
#
# <unk> N look $ the a use do hold buy pay raise cut offer be take see several increase provide
# that 's when george l. ball chairman of the prudential ___
#
# <eos> <unk> of 's in and group or for which has said future was are committee bond industry center '
# i have a <unk> that this particular decline today is ___
#
# <unk> a n't the not likely an at being seeking how used <eos> that in scheduled $ trading convertible so
# it would be my <unk> to advise clients not to ___
#
# <unk> the meet a $ build N see be provide hold make acquire president his begin set its allow purchase
# at merrill lynch & co. the nation 's biggest brokerage ___
#
# firms <eos> a firm <unk> the corp. which led to of said and hours at is executives that it group
# the release cautioned that there are significant differences between the ___
#
# <unk> recent two government company big loan industry u.s. test fact the sale year-earlier number firm time level month companies
# however jeffrey b. lane president of shearson lehman hutton inc. ___
#
# unit <unk> said the a is posted of will it has at had which was and los <eos> an plans
# and i think a lot of people will <unk> on ___
#
# <unk> oct. $ dec. the a these friday tuesday april new such business nov. other five stock volume monday program
# it 's going to bring the debate right back to ___
#
# <unk> $ N a see the full give acquire make pay be keep buy have help do purchase produce sell
# as the dow average ground to its final N loss ___
#
# of and the or to in <eos> from by for <unk> $ germany shares a german since that index as
# jeffrey <unk> of program trader <unk> investment group said N ___
#
# N <eos> and for to shares stock <unk> fell would of million will could into on has with was at
# while friday 's debacle involved mainly professional traders rather than ___
#
# a the $ many any <unk> expected an it there N that some one made <eos> previously to been just
# stock-index futures contracts settled at much lower prices than indexes ___
#
# the by of and a for exchange into are <eos> in to about its <unk> said loan from damage '
# at those levels stocks are set up to be <unk> ___
#
# <eos> by <unk> to for the after N its 's as in and about that has into because their back
# but nobody knows at what level the futures and stocks ___
#
# in of <unk> to on are <eos> with for at and as stocks were traded will would taxes because is
# the <unk> between the stock and futures markets friday will ___
#
# be <unk> come remain take continue have buy include also sell cost rise receive return exchange test the give cut
# the big board 's mr. <unk> said our <unk> performance ___
#
# a the to <eos> of <unk> with will as are this for and by its have who between or that
# but the exchange will look at the performance of all ___
#
# <unk> it of <eos> but stocks the with that in one stock mr. shares for at interest business companies countries
# obviously we 'll take a close look at any situation ___
#
# <unk> have are in for 's trading ' do with can of securities place were the retail and a boston
# see related story fed ready to <unk> big funds wsj ___
#
# <eos> the a by <unk> in to N $ are at would and that had of as with an is
# but specialists complain privately that just as in the N ___
#
# N period <eos> <unk> quarter was million six stock fiscal third up for to through months or would administration business
# mr. phelan said it will take another day or two ___
#
# in of to <unk> with prices cents <eos> higher a canadian on or different yield companies years approval for who
# concerning your sept. N page-one article on prince charles and ___
#
# <unk> the a N exchange it is other at was by to has chief related mr. that construction more for
# it 's now the united kingdom of great britain and ___
#
# <unk> a the in to $ N related by gas some it other at that for futures robert an sold
# ports of call inc. reached agreements to sell its remaining ___
#
# <unk> in of to <eos> by said that 's profit and businesses buying a despite gain which its with business
# the agreements bring to a total of nine the number ___
#
# of to <unk> <eos> for 's it they said but market ended rate by the with or is and be
# the company said a portion of the $ N million ___
#
# <eos> of in and for or loss from on to at <unk> face said compared a that 's charge the
# earlier the company announced it would sell its aging fleet ___
#
# to for <eos> by <unk> the 's and as in notes of a on said plant national its that with
# a consortium of private investors operating as <unk> funding co. ___
#
# and <eos> <unk> with for 's unit the is was N a on chief in business of posted new manager
# the $ N million bid includes the assumption of an ___
#
# <unk> additional interest investment estimated $ office independent increase agreement N equity companies oil expected the old insurance auto important
# the group is led by jay <unk> chief executive officer ___
#
# <eos> of a and have <unk> would for had but up the by was said is or on as compared
# mr. <unk> 's company specializes in commercial real-estate investment and ___
#
# <unk> a the are in is that it $ not to for other of by an were N mr. <eos>
# the assets are good but they require more money and ___
#
# <unk> a chief N the directors so is not securities <eos> investment it loan less commercial japan $ does financial
# l.j. hooker based in atlanta is operating with protection from ___
#
# <unk> a creditors the its N no their several out some other one up u.s. for and an what such
# its parent company hooker corp. of sydney australia is currently ___
#
# <eos> of at <unk> the by and as with to for in on a but that trying it under an
# sanford <unk> chief executive of l.j. hooker said yesterday in ___
#
# <unk> a the london new this its april los heavy august south his which an recent addition other future several
# the $ N million bid is estimated by mr. simpson ___
#
# <eos> 's and said the of for as <unk> that is with has group but who its N made by
# not included in the bid are <unk> teller or b. ___
#
# <eos> a for <unk> the of that and an with losses by public number in $ it or at to
# the offer covers the massive N <unk> forest fair mall ___
#
# <eos> the by and for of a to said losses is at with an inc. 's as <unk> between has
# the <unk> mall opened sept. N with a <unk> 's ___
#
# <unk> N proposal shares price board agreement performance official market to third year strategy tax u.s. leading office business loss
# other hooker properties included are a <unk> office tower in ___
#
# the <unk> a this los his london south new its such recent N several august it future return which federal
# the consortium was put together by <unk> <unk> the london-based ___
#
# of <eos> <unk> for by and the 's with rate is was has industry or loan ' future to are
# we do n't anticipate any problems in raising the funding ___
#
# <unk> <eos> of for 's the are was in has loan and ' group with test could is said to
# according to people familiar with the consortium the bid was ___
#
# a <eos> n't <unk> $ largely no it up less made of nearly used down too at reduced expected have
# l.j. hooker was a small <unk> company based in atlanta ___
#
# the <unk> 's profit <eos> and in N is has to for fund a trading already said with net as
# the company grew modestly until N when a majority position ___
#
# of to <unk> approved my it mr. N on is shearson commercial <eos> and in like yesterday that as the
# mr. <unk> <unk> to launch an ambitious but <unk> $ ___
#
# N the <unk> $ n't march to not this sales a april tuesday half is one little other large by
# eventually mr. simpson and mr. <unk> had a falling out ___
#
# of to the interest <eos> <unk> sales and on $ from it a during products as this was money is
# since then hooker corp. has sold its interest in the ___
#
# <unk> third quarter second first stock case u.s. market area year federal N fiscal past car end london bay new
# in addition robert <unk> chief executive of the <unk> chain ___
#
# <eos> <unk> said the and for to of by which a 's is are at on notes group in bond
# the merksamer chain is currently being offered for sale by ___
#
# <unk> the its a $ year it two N first an assets congress those s&p stock time all he institutions
# reached in <unk> mr. <unk> said that he believes the ___
#
# <unk> government sale european firm federal way agency recent center nation kind the first change most exchange area u.s. offer
# these are n't mature assets but they have the potential ___
#
# <unk> of on said in year is they impact estimate and over it for u.s. 's at <eos> under rates
# managed properly and with a long-term outlook these can become ___
#
# <eos> the of that a in <unk> to for 's at and $ as it stocks would said this chairman
# canadian <unk> production totaled N metric tons in the week ___
#
# ended of for said <eos> <unk> was 's to is but also by rate market would it at has and
# the week 's total was up N N from N ___
#
# N million <eos> shares billion <unk> and cents a yen transportation stock years at from or share on common for
# the <unk> total was N tons up N N from ___
#
# N a $ <unk> the its august three up september at year two last nov. about only some in july
# the treasury plans to raise $ N million in new ___
#
# york <unk> N line trading $ debt stock issues <eos> third market contract capital profit machines year-earlier series net loans
# the bills will be dated oct. N and will mature ___
#
# the <unk> <eos> its by and in that 's a all N about as have dow holders work back off
# bids must be received by N p.m. edt thursday at ___
#
# <unk> least the it a that of mr. work earlier last $ best by more five this its an they
# as small investors <unk> their mutual funds with phone calls ___
#
# <unk> of for and yesterday on a this the after <eos> unit court u.s. than in to said was it
# unlike the weekend before black monday the funds were n't ___
#
# <unk> disclosed expected work the open already to have it changed not just a yet still be they see only
# and many fund managers have built up cash levels and ___
#
# <unk> N $ is was in caused also has are some given does closed exchange britain help work damage that
# at fidelity investments the nation 's largest fund company telephone ___
#
# <unk> of to <eos> for in that or a by spending on and if from when 's the bank profit
# the boston firm said <unk> redemptions were running at less ___
#
# than <unk> to of for <eos> on who the in very and price a $ at also with are expected
# as of yesterday afternoon the redemptions represented less than N ___
#
# N shares a and million <eos> by yen of point years for up on <unk> percentage at other had from
# two years ago there were massive redemption levels over the ___
#
# <unk> past next first third recent most best sale latest quarter year-earlier same street summer prime biggest a the dollar
# friday 's stock market sell-off came too late for many ___
#
# <unk> of <eos> days as N women and programs a the agency companies years people investors junk chairman last with
# some shareholders have held off until today because any fund ___
#
# n't <unk> not be and said have the still by see prices as already was inc. has do at march
# stock fund redemptions during the N debacle did n't begin ___
#
# for <eos> a until to since by from <unk> and of would german on division selling paid although the out
# many have raised cash levels which act as a buffer ___
#
# <unk> <eos> of N in for and or firm measure above to by offer company test net project amount executive
# mario <unk> for instance holds cash positions well above N ___
#
# N cents for and <eos> million to a <unk> shares by through within of at machines or in on will
# windsor fund 's john <unk> and mutual series ' michael ___
#
# <unk> <eos> a have is N to marketing for had paid n't and would filed want how priced of which
# even peter lynch manager of fidelity 's $ N billion ___
#
# <eos> in a from to that and said of bid on $ for since <unk> no or will had at
# one reason is that after two years of monthly net ___
#
# income <unk> rose of <eos> in inc. fell and is said group loss for was to were not paid which
# i 've let the money build up mr. lynch said ___
#
# <eos> its <unk> it the he a they N that for at by as his one we all this when
# as a group stock funds held N N of assets ___
#
# <unk> <eos> in to due by or stock that and securities for from on compared the into loans airlines bonds
# that was modestly higher than the N N and N ___
#
# N shares million <unk> a from for <eos> and of by stock on or after before up the while cents
# also persistent redemptions would force some fund managers to dump ___
#
# the <unk> a its <eos> and their with about as customers by N whether that in for an 's are
# but a strong level of investor withdrawals is much more ___
#
# <unk> than of $ money the for <eos> at rate in volatility said important N industry better often efforts problems
# a major reason is that investors already have sharply scaled ___
#
# the by to for on <unk> of in 's and <eos> a that under inc. said or as between with
# <unk> sales have rebounded in recent months but monthly net ___
#
# income <unk> was fell loss rose worth <eos> is of for in costs by as to inc. not and business
# there 's not nearly as much <unk> said john <unk> ___
#
# <unk> the by a an <eos> of and in for already as its that it 's has to would which
# many fund managers argue that now 's the time to ___
#
# be <unk> see a take do have the get report provide boost $ come pay return reduce give mr. purchase
# vincent <unk> manager of the $ N billion wellington fund ___
#
# <unk> <eos> said by and has to for unit not damage than largely bills the at earlier be n't concern
# and today he 'll be looking to buy drug stocks ___
#
# in of to <unk> and <eos> at said on as loan bonds since payments were for issued stocks that yesterday
# fidelity 's mr. lynch for his part snapped up southern ___
#
# <eos> <unk> the and loan a by for with 's of their an N that in at co. or has
# if the market drops further today he said he 'll ___
#
# to <unk> a at only take about buy n't the never do as continue no april sell make now back
# if they <unk> stocks like that he said it presents ___
#
# <unk> the its <eos> a by and as to in an them that are 's has for all about it
# major mutual-fund groups said phone calls were <unk> at twice ___
#
# the <unk> <eos> a in for N of 's and which an by with its their held about that at
# they hope to avoid the <unk> phone lines and other ___
#
# <unk> <eos> financial products corp company industries operations goods areas countries for directors services food 's industrial states in cases
# fidelity on saturday opened its N <unk> investor centers across ___
#
# <eos> by the and for to of said a <unk> 's that is so his this concern as which at
# in addition east coast centers will open at N edt ___
#
# of <eos> <unk> and in 's a by the that with as has for to would an or from on
# t. rowe price associates inc. increased its staff of phone ___
#
# <eos> <unk> management in the 's corp corp. and which assets or holdings common national loans group has N policy
# the <unk> group noted that some investors moved money from ___
#
# the N <unk> a $ an three its last in their government seven women mr. his not some japan it
# but most investors seemed to be in an information mode ___
#
# <unk> a the <eos> by to for in its $ N with an and at made as because is has
# and vanguard among other groups said it was adding more ___
#
# than <unk> the to in and director at back <eos> for of shares said operations as money but or changes
# in an unusual move several funds moved to calm investors ___
#
# <eos> to and would on after will is who a had have <unk> was into said with losses ' as
# we view friday 's market decline as offering us a ___
#
# <unk> year N share month new percentage return strong point day $ lot yield unit major week special federal few
# several fund managers expect a rough market this morning before ___
#
# the to it and as they by <eos> <unk> this that he in with mr. for or a but since
# some early selling is likely to stem from investors and ___
#
# <unk> a N the <eos> san chief loan so not that $ women is trading investment for may it of
# stock funds have averaged a staggering gain of N N ___
#
# N of and shares or <unk> <eos> to for from bonds a bond with in would index by standard at
# <unk> <unk> who runs shearson lehman hutton inc. 's $ ___
#
# N <unk> $ the n't not airlines half is june program stock group trading april july said a first division
# but she expects prices to rebound soon and is telling ___
#
# <eos> in <unk> by the a and to of as that an treasury for are paid at it on its
# nevertheless ms. <unk> said she was <unk> with phone calls ___
#
# of for <unk> and a on this yesterday by unit during <eos> is the co. 's after said was at
# half of them are really scared and want to sell ___
#
# its the a $ <unk> orders programs <eos> in by all their today about for it last off and to
# she added if they all were bullish i 'd really ___
#
# <unk> is the said this to will has 's it have would by <eos> says had he were they that
# the backdrop to friday 's slide was <unk> different from ___
#
# the a N its london $ profit <unk> an their august september his yesterday higher lower last about june both
# two years ago unlike today the dollar was weak interest ___
#
# rates in to said costs on <unk> at by N income but payments also paid 's management position as have
# from the investors ' standpoint institutions and individuals learned a ___
#
# <unk> N unit european new huge month $ government special university number takeover small problem series gain decline food car
# this time i do n't think we 'll get a ___
#
# N <unk> lot percentage small new third second few special large year recent decline settlement subsidiary way unit product takeover
# newport corp. said it expects to report <unk> earnings of ___
#
# <unk> the $ economic N its a government revenue this japan assets credit chief capital last program new shares united
# the maker of scientific instruments and laser parts said orders ___
#
# by <unk> would for to are were and <eos> into 's of will who firm said index against at is
# a spokesman added that sales in the current quarter will ___
#
# <unk> be also rate exchange auction charge include continue added issue take only decline probably are with trade administration likely
# <unk> from the strike by N machinists union members against ___
#
# <unk> the as program such a these that all it 's this what him for in and its mr. effort
# peter <unk> vice president for planning at the phoenix ariz. ___
#
# <eos> and <unk> of for the by to said 's or a are which with in is bond as that
# mr. <unk> said boeing told america west that the N ___
#
# N <unk> shares was million could or price stock is of a bond points quarter rate has for earthquake will
# boeing is also supposed to send to america west another ___
#
# <unk> to n't at or from cut debt be a higher marks <eos> early fall more N that in of
# at this point no other america west flights including its ___
#
# <unk> N share as own previous $ financial third-quarter business revenue <eos> stake current high a for recent more offer
# nevertheless the company 's reaction <unk> the <unk> effect that ___
#
# the it are <unk> a at is mr. there they he we would was has no N for an makes
# it also is sure to help the machinists put added ___
#
# the for N <eos> as and a it to that in an into mr. on at with or up by
# i just do n't feel that the company can really ___
#
# <unk> is included the to at $ it are an in if could staff division <eos> he N airlines some
# i do n't think their customers would like it very ___
#
# <unk> of little on clear different much and very good costs if not has again also agreed take completed said
# america west though is a smaller airline and therefore more ___
#
# <unk> than the association business said money and shares <eos> other of maker programs in tax to important businesses now
# i figure that american and united probably have such a ___
#
# <unk> month share few spokesman N new unit stake gain rate little leading year huge university record proposal more loss
# indeed a random check friday did n't seem to indicate ___
#
# the a <unk> <eos> its for their in an with by and any back at N about as it off
# southwest airlines has a boeing N set for delivery at ___
#
# N its the a <unk> least all $ an trading about operating to first work it august and as any
# it 's so close to completion boeing 's told us ___
#
# by at to <eos> <unk> as the a for on $ that its would increase of in and since volume
# a spokesman for amr corp. said boeing has assured american ___
#
# <unk> medical a stock <eos> the this to by new other at airlines for trust of and that telephone companies
# american is preparing to take delivery of another N in ___
#
# a <unk> the new august its which september at assets april an N ual some cash this what no growth
# in seattle a boeing spokesman explained that the company has ___
#
# n't <unk> had been a N <eos> not about become said the interests asked since are lost at made and
# meanwhile supervisors and <unk> employees have been trying to finish ___
#
# the its <eos> <unk> by to a an about for their which has as N 's because back into and
# as of friday four had been delivered and a fifth ___
#
# <eos> <unk> of for in concern by that $ work and amount N plan test gain fund which to maker
# no date has yet been set to get back to ___
#
# <unk> N buy a $ full acquire pay provide be the see come call reduce do give purchase most their
# we want to make sure they know what they want ___
#
# <eos> a it and mr. N over in the to <unk> out doing he me on for this all up
# the investment community for one has been anticipating a <unk> ___
#
# of <eos> <unk> in N by for and $ the program or with gain stock to that test exchange amount
# though boeing 's stock price was battered along with the ___
#
# <unk> recent first a securities most $ latest loan big state company federal small u.s. same losses kind public offer
# the market has taken two views that the labor situation ___
#
# <unk> <eos> a are were 's and should also is have with securities which could it for will has can
# boeing 's shares fell $ N friday to close at ___
#
# $ a <unk> the about least N its all their to an higher last high first lower work that two
# but mr. baker said he thinks the earliest a pact ___
#
# of in <unk> <eos> for with and N $ test that fund program the by amount or loan area stock
# still he said it 's possible that the strike could ___
#
# n't be <unk> have get still go make is become provide take were are continue also change to not result
# last week boeing chairman frank <unk> sent striking workers a ___
#
# <unk> unit $ vice large school small N huge a recent similar few government long year new further credit rate
# but mr. baker called the letter and the company 's ___
#
# net <unk> $ board annual shares earnings a largest N office debt loss first stock price share recent proposal more
# he added that the company <unk> the union 's resolve ___
#
# <unk> <eos> and in on for to director said of as by program position policy system bank at index office
# in separate developments talks have broken off between machinists representatives ___
#
# and <eos> the <unk> by of to for a in with its that & are which on were 's N
# the union is continuing to work through its expired contract ___
#
# <eos> to <unk> would with and were are the on is as have in will a at that for N
# it had planned a strike vote for next sunday but ___
#
# the <unk> as it they <eos> to in he by that would a only and with its mr. were not
# united auto workers local N which represents N workers at ___
#
# a <unk> least $ the its N an work last this shearson about five one it more some first that
# and boeing on friday said it received an order from ___
#
# a the N $ <unk> its three at taxes <eos> an his their about august it down june both one
# the planes long range versions of the <unk> <unk> will ___
#
# be <unk> become not run allow business provide show management cost raise remain continue also the decline go come take
# a boeing spokeswoman said a delivery date for the planes ___
#
# <eos> <unk> of for by and month has the a is was at industry 's rate group in period to
# <unk> ltd. said its utilities arm is considering building new ___
#
# york <unk> are the $ have general government issues mr. directors a <eos> state corporate issue stock bond ever workers
# <unk> <unk> <unk> 's senior vice president finance said its ___
#
# <unk> first latest face management business fiscal current third-quarter cash board investment offer total three N paper european performance exchange
# but we would n't go into them alone and canadian ___
#
# <unk> <eos> government a officials the are who or and dollars programs orders for of workers ' an pacific will
# <unk> we 'd like to be the operator of the ___
#
# <unk> loan recent department company companies test new federal stock market currency group insurance government national talks shares school program
# our long suit is our proven ability to operate power ___
#
# co. for by and <eos> <unk> plant inc. said of to at unit the which a after executive would from
# mr. <unk> would n't offer <unk> regarding <unk> 's proposed ___
#
# <unk> $ <eos> interest community manager value losses public unit group late move for next test offer of bush work
# britain 's government plans to raise about # N billion ___
#
# in to <eos> that <unk> a of from on $ yen and for up not under bid stake N gain
# the planned electric utility sale scheduled for next year is ___
#
# <unk> n't that the in a <eos> $ expected worth seeking an not beginning likely more based about also they
# under terms of the plan independent <unk> would be able ___
#
# to <unk> by into for at but back its and a officials the as them 's N more <eos> something
# canadian utilities had N revenue of c$ N billion mainly ___
#
# <unk> by $ for <eos> the at and in a said 's of assets as to has its N president
# there seems to be a move around the world to ___
#
# <unk> see a $ be the lower do give have make become its help go take provide know come nearly
# this is a real thrust on our utility side he ___
#
# said of added is paid says for the <unk> and was are can adds would dropped called had with sold
# canadian utilities is n't alone in exploring power generation opportunities ___
#
# by <eos> a the to of and inc. for is <unk> said this with in so but on under 's
# we 're certainly looking at some power generating projects in ___
#
# the <unk> a august an its it growth school los south this third-quarter fact financing which his japan late recent
# mr. <unk> said enron is considering building <unk> power plants ___
#
# <unk> with to in n't that for <eos> a also years at among are but between the group and things
# pse inc. said it expects to report third earnings of ___
#
# <unk> the $ N its reserves a corporate about texas economic this japan manufacturers u.s. capital return six last government
# in the year-ago quarter the designer and operator of <unk> ___
#
# the <unk> <eos> in which management 's corp. with and stock of national by for loans loan has are inc.
# the company said the improvement is related to additional <unk> ___
#
# the <unk> about rates its for <eos> 's and by to a national after how approval costs of us said
# <unk> <unk> flights are $ N to paris and $ ___
#
# N <unk> the $ a oct. businesses shares n't one more from group at volume only june not airlines for
# in a centennial journal article oct. N the fares were ___
#
# n't <unk> <eos> said $ closed among up largely by about made outstanding and a at the issued using N
# diamond <unk> offshore partners said it had discovered gas offshore ___
#
# the by <eos> for in <unk> $ to at of with N and a through an was are into its
# the well <unk> at a rate of N million cubic ___
#
# <unk> the a in by for to <eos> $ N its dollars shares on and up at off from or
# diamond <unk> is the operator with a N N interest ___
#
# rate N in yield rates at from <unk> to on up rise and for 's charge a by year said
# diamond <unk> offshore 's stock rose N cents friday to ___
#
# N <unk> $ the remain buy close do provide be a return vote build sell about come take lower see
# <unk> & broad home corp. said it formed a $ ___
#
# N $ the <unk> for one program time not stock that television exchange only july three of or oct. to
# the partnership <unk> & broad land development venture limited partnership ___
#
# <unk> the <eos> and as in is N that by about while 's its a to for which motor with
# <unk> & broad a home building company declined to identify ___
#
# the <unk> its their N 's a an back <eos> about to by and because as today for in such
# the land to be purchased by the joint venture has ___
#
# <unk> to of had N <eos> in by since are been for increased a said at agreed ended already and
# the partnership runs the risk that it may not get ___
#
# <unk> the a back whether its how on an their another more to going for in any <eos> last out
# there are really very few companies that have adequate capital ___
#
# <unk> in <eos> gains markets to for the at on management base as a 's by inc. under and back
# typically developers option property and then once they get the ___
#
# <unk> N second first year-earlier $ company third month quarter transaction same federal rate fourth situation national close latest fact
# by setting up the joint venture <unk> & broad can ___
#
# <unk> be provide to produce said at make <eos> not use and turn would for corp. u.s. n't find still
# the company is putting up only N N of the ___
#
# <unk> common shares federal stock N work board u.s. second company national dollar recent first new issue three previous dow
# this is one of the best ways to assure a ___
#
# <unk> new unit large N $ huge second federal bid takeover further major university government proposal decline capital joint similar
# when the price of plastics took off in N quantum ___
#
# <eos> and a by of its for the as with to in said because <unk> are would that it $
# the timing of quantum 's chief executive officer john <unk> ___
#
# <eos> <unk> by the a and to for in of stock its at 's trading new bond said that an
# the company <unk> much of the chemical industry as annual ___
#
# sales <unk> as the and revenue expected august june for rates march volume <eos> seen trying what do costs estimated
# mr. <unk> said of the boom it 's going to ___
#
# be see <unk> sell do make help go reduce acquire provide get build buy the N take meet cut have
# but now prices have <unk> and quantum 's profit is ___
#
# <unk> a n't <eos> seeking expected likely part completed that the being an not known at trying cut called making
# some securities analysts are looking for no better than break-even ___
#
# by and the a its about of <eos> <unk> to for as their year N in said at how from
# the stock having lost nearly a quarter of its value ___
#
# of in <eos> to with <unk> and that for by ended or as including says but said at volume a
# to a degree quantum represents the new times that have ___
#
# <unk> n't been failed an to the for offered a reduced officials reported had given and different with no become
# having just passed through one of the most profitable periods ___
#
# <eos> to <unk> the for and by of in with that on as a unit said at 's concern it
# pricing cycles to be sure are nothing new for plastics ___
#
# and <unk> <eos> by for 's the of with that has in at said a inc. N losses to under
# and the financial decline of some looks steep only in ___
#
# a the <unk> los its this an chicago europe his small recent at london N one south it what new
# we were all wonderful heroes last year says an executive ___
#
# <eos> vice and is at a of said <unk> which with director account or for earnings has journal in while
# at quantum which is based in new york the trouble ___
#
# <unk> <eos> of 's to said by rate bond in and was could number composite or has is the stock
# once known as national <unk> & chemical corp. the company ___
#
# 's said will to <eos> reported was has <unk> for and is also of that sold agreed would had did
# mr. <unk> N years old declined to be interviewed for ___
#
# a <unk> the future companies programs as $ their other its five two business new about fiscal more several jaguar
# quantum 's lot is mostly tied to polyethylene <unk> used ___
#
# to as a the <eos> <unk> for in at by that of on its with about over since their when
# in the u.s. polyethylene market quantum has claimed the largest ___
#
# N <unk> group stock shares government index $ was the of market board for department law and are said number
# but its competitors including dow chemical co. union carbide corp. ___
#
# said <unk> and unit to <eos> completed of for executive in proposed subsidiary which at on from shares 's offer
# when the price of polyethylene moves a mere penny a ___
#
# <unk> unit N new huge loss takeover european government year firm month percentage group special major recent change problem gain
# in recent months the price of polyethylene even more than ___
#
# a N $ <unk> of the that many for <eos> used as being half sales an to i one we
# benchmark grades which still sold for as much as N ___
#
# N million percentage <unk> and up shares <eos> a point cents as was off of the from for to or
# meanwhile the price of <unk> the chemical building block of ___
#
# <unk> the this course a los capital N economic new its california shares short future business personal dollars information other
# that <unk> <unk> quantum badly because its own plants cover ___
#
# the by <unk> to in inc. 's of <eos> said and N management corp. stock has are assets did about
# by many accounts an early hint of a price rout ___
#
# <unk> to the and in of <eos> for by said held which a N at are is would just he
# china which had been putting in huge orders for polyethylene ___
#
# <unk> the and N in by are an <eos> with that j. have of charge profit is 's has a
# <unk> that excess polyethylene would soon be <unk> around the ___
#
# <unk> government recent fact loan company new insurance office problems market country problem european the university public nation average division
# kenneth mitchell director of dow 's polyethylene business says producers ___
#
# to <unk> of at <eos> for and is had said how with & but a the by under that will
# they recently announced increases of a few cents a pound ___
#
# of <unk> <eos> N in rise for $ auction below to above by and concern with that conference more brokerage
# no one knows however whether the new posted prices will ___
#
# be continue also <unk> fall decline receive cost have allow rate begin point move trade drop the rise remain rates
# one <unk> is george <unk> a <unk> analyst at oppenheimer ___
#
# <eos> <unk> a the by for 's an in national and has that securities brokerage at which such led to
# noting others ' estimates of when price increases can be ___
#
# <unk> no used a better paid able made sold it in to reduced bought acquired the put around concern <eos>
# he argues that efforts to firm up prices will be ___
#
# <unk> paid used made in higher able sold more among much a limited that worth one given far hard announced
# a quick turnaround is crucial to quantum because its cash ___
#
# value <unk> and but a as <eos> have on major mr. to reserves for in only at the recent that
# the company is trying to carry out a three-year $ ___
#
# N to <unk> n't the year day is $ sales exchange five within april two new march and central said
# at the same time its annual payments on long-term debt ___
#
# <unk> to stock $ issues about the in <eos> its yesterday that for rose 's from of assets N offering
# quantum described the payout at the time as a way ___
#
# <unk> <eos> of to for and N toward ago in that earlier net at or could with on morgan is
# some analysts saw the payment as an effort also to ___
#
# <unk> the be $ a N provide take finance see make turn give other acquire pay do come mr. have
# whether a cash crunch might eventually force the company to ___
#
# <unk> be $ yield a N buy give increase go boost take make meet help open pay purchase sell begin
# some viewed his response that company directors review the dividend ___
#
# of <eos> <unk> to for and month or rate was the on with business exchange government has they group that
# but others came away thinking he had given something less ___
#
# than <unk> to of on who in as <eos> first often at about more for the figures and full is
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# in any case on the day of the meeting quantum ___
#
# <unk> <eos> the and 's said which for a of how held that or group to common in is has
# on top of everything else quantum <unk> a disaster at ___
#
# least a the <unk> $ to this N first about an its best last by all home it money more
# after an explosion <unk> the plant in june the company ___
#
# 's was will said has is <eos> also reported to could had would <unk> of agreed can that for expects
# this human toll adds the most painful <unk> yet to ___
#
# a $ the <unk> meet N acquire mr. make an do produce be his help hold buy reduce not yield
# until this year the company had been steadily lowering its ___
#
# <unk> offer stake own the N business investment european huge as three board shares operating <eos> previous earlier parent third-quarter
# a prolonged production halt at the plant could introduce another ___
#
# <unk> to at a and or dollars <eos> by shares that this such the said dec. of in medical you
# when a plant has just been running flat out to ___
#
# the a sell <unk> be do see make president an acquire its keep $ control provide help any pay buy
# but the numbers become <unk> and subject to <unk> between ___
#
# the <unk> such N a it $ their they <eos> stocks new growth its two brokers to investors construction for
# you say you could have sold x percent of this ___
#
# <unk> <eos> of is interest country kind policy old week loan losses school for and year at or not time
# quantum hopes the morris plant where limited production got under ___
#
# the mr. a N <unk> its $ current it way pressure this an friday four more 's our their past
# the plant usually accounts for N N to N N ___
#
# <eos> and after from N of to for on yen tuesday would stake because shares share but in with at
# the plant expansion should strengthen the company 's <unk> in ___
#
# the <unk> new a this N its los august london which several cash unit his september europe business such federal
# by lifting <unk> production the expansion will also lower the ___
#
# <unk> transaction test number sale issue market economy board stock spokesman latest problem basis offering restructuring treasury u.s. gain second
# quantum is also tightening its grip on its one large ___
#
# <unk> number amount earnings of N shares stock two point offering a increase system price profits official stores executive in
# through a venture with its investment banker first boston corp. ___
#
# <unk> of said and unit a for 's yen at <eos> in from or $ which to increase group was
# some analysts speculate the weakening stock may yet attract a ___
#
# <unk> N new unit little position car suit huge takeover major bid recent second gain long maker private problem small
# the name <unk> in rumors is british petroleum co. which ___
#
# the has is are would <unk> ended had owns makes were a it said also can was by in an
# asked about a bid for quantum a <unk> spokesman says ___
#
# the <unk> a <eos> john that is an david mr. he will of its has and i sen. had in
# rjr nabisco inc. is <unk> its division responsible for buying ___
#
# <unk> the shares and <eos> a at 's of to an more in plans for but said markets is lynch
# a spokesman for the new york-based food and tobacco giant ___
#
# <eos> <unk> the said has co. for 's of by in to have management maker and is inc. which are
# the spokesman said rjr is discussing its <unk> plans with ___
#
# the a <unk> an more mr. N government its $ those and it european every different their high other new
# we found with the size of our media purchases that ___
#
# the is he are they N <unk> this mr. was will it a for we do of makes includes has
# an executive close to the company said rjr is spending ___
#
# of in to <eos> as and by for <unk> a at on that it but the years or rates up
# ...
# that became clear last week with the disclosure that national ___
#
# <unk> product a policy recent markets the security steel interest not association corp. program bank n't said office institutions is
# nbc 's interest may revive the deal which mgm\/ua killed ___
#
# <unk> <eos> the by in and of to said for 's a that had with ' & are at because
# even if that deal is n't revived nbc hopes to ___
#
# the <unk> a this $ provide acquire be make see do his mr. become meet reduce is keep build help
# nbc may yet find a way to take a passive ___
#
# in <unk> <eos> of $ N month for and offer test with above that by position between or from bid
# and any nbc effort could prompt cbs inc. and abc ___
#
# <unk> of <eos> a the concern by and for said operations group to maker in would 's has its it
# but the networks ' push may only <unk> an increasingly ___
#
# <eos> <unk> with of the for and in number to that which by program said N an $ a it
# both sides are to sit down next month for yet ___
#
# <unk> to and of it <eos> in fell from at force within last for this $ its on a N
# few people <unk> to the talks expect the studios to ___
#
# be <unk> provide the see a his take go have this get return show build several use buy give $
# the networks still are <unk> in their authority over what ___
#
# a <unk> the to that it at an they lost losses we such i there as next recently of volume
# studios are <unk> to get shows in prime-time <unk> and ___
#
# <unk> the a not is was related to no other it in loan at directors an by for has construction
# and that 's why the rules for the most part ___
#
# of oct. <eos> to <unk> said that and as on the are were sept. will for they is at it
# studio executives in on the talks including officials at paramount ___
#
# <unk> the N <eos> by that a 's under in to of $ about whether for because and its with
# but mr. <unk> who represents the studios asserts the whole ___
#
# of <eos> <unk> for by and the 's with rate is was has industry or loan ' future to are
# such <unk> leave network officials all the more doubtful that ___
#
# the <unk> it is are they to this a he on N there mr. provide as new makes if of
# they do n't seem to have an incentive to negotiate ___
#
# the its <eos> a <unk> an by about their for as with and N $ back 's any or at
# and there 's no indication that washington is prepared to ___
#
# <unk> see be build the go N do this yield cut take provide have reduce use a become $ gain
# congress has said repeatedly it wants no part of the ___
#
# <unk> work currency federal N kind decline problem transaction big national treasury time recent stock u.s. first firm company test
# but recent developments have made the networks and nbc president ___
#
# of and <eos> by for bush at to said <unk> will 's chief would in is were or reported has
# the latest <unk> sony corp. 's plan to acquire columbia ___
#
# <unk> in such market for analysts and <eos> or stocks of N securities as who position the that exchange banking
# i wonder what walter <unk> will think of the <unk> ___
#
# <unk> <eos> of or 's and in group for the concern computer has to ' with national should was public
# in his article mr. <unk> who was in europe last ___
#
# month week august year <unk> friday and july <eos> december day sales stock april thursday two monday area half six
# he did n't mention that nbc in the meantime was ___
#
# <unk> <eos> n't a no $ the seeking too have it also said made left far largely not closed still
# an nbc spokesman <unk> that mr. <unk> 's <unk> was ___
#
# <eos> a <unk> n't closed $ the named no seeking it particularly this led N reduced would an sold due
# the big three 's <unk> for deregulation began <unk> in ___
#
# the <unk> this a several south his los large europe new its such which august london recent chicago april treasury
# although time already had a long-term contract to buy movies ___
#
# <eos> <unk> by to in for the bond its and exchange a profits with of insurance damage ' after their
# nbc 's mr. wright led the way in <unk> the ___
#
# <unk> first new proposed offer plant industry federal change system sale insurance most buy-out two future latest period general statement
# he spoke up again when the sony bid for columbia ___
#
# and <unk> by a programs late the <eos> at N was of would for has volume in university is as
# since nbc 's interest in the qintex bid for mgm\/ua ___
#
# <unk> by <eos> and a 's the in said has losses of an at for programs $ but that would
# with a qintex deal nbc would move into <unk> territory ___
#
# <eos> <unk> and by a to the for which of in holdings or loan 's as inc. between with that
# it 's never really been tested says william <unk> iii ___
#
# and <unk> director <eos> by the of in on for a are 's group to at N has said as
# he now runs policy communications in washington consulting to media ___
#
# the <unk> <eos> with their its a an in by whether for high and or it about as back customers
# <unk> rules do n't <unk> block a network from buying ___
#
# <unk> 's said operations price reported in for businesses of transportation investors shares estimates unit <eos> industries and concern more
# hence nbc might be able to take say a N ___
#
# N of <unk> <eos> $ for stock price marks years percentage shares million in that after days and cents or
# if the transaction raised objections the studio 's <unk> operations ___
#
# <eos> to the by is a in and than for has this are <unk> had as since were on with
# but such <unk> would still block the networks from <unk> ___
#
# <eos> <unk> for in the and of with a by national to are at that operations school said on 's
# under current rules even when a network fares well with ___
#
# a the <unk> N $ its an shares more any those their <eos> and different it mr. returns that government
# instead abc will have to sell off the rights for ___
#
# a the its <unk> years example $ an N two about all their more others much one any companies new
# the networks admit that the chances of getting the relief ___
#
# <unk> of <eos> to the for 's in are stock group public by said and number held industry ' family
# the <unk> federal communications commission had ruled in favor of ___
#
# <unk> $ the a future this economic dollars los business N its new course his all credit about it industry
# various evidence including a <unk> institution study of some N ___
#
# N shares million of a <eos> to the <unk> or by cars and would for bond in stock workers points
# but just eight days before the rules were to die ___
#
# <unk> the <eos> a in its their with about by and additional to an that N or high 's for
# network officials involved in the studio talks may hope the ___
#
# <unk> federal new european most first N benefits use fact the sale california issue big government west situation central test
# in congress the issue <unk> it 's about money not ___
#
# <unk> a the to as only in your all be officials currently good six yet 's has find <eos> many
# a spokesman for rep. edward j. markey <unk> who heads ___
#
# <eos> the by and a in its <unk> for losses at as an with that of under 's not to
# but he said mr. markey hopes this <unk> the networks ___
#
# of <unk> <eos> the for by are to 's was with ' in could group and or has is N
# and at the fcc meanwhile new chairman alfred c. <unk> ___
#
# <eos> and the for by of as <unk> a with to 's said in which losses an between at management
# recognition equipment inc. said it settled a civil action filed ___
#
# <unk> the are n't in a <eos> officials were it estimates said analysts is too at had buy with investors
# the government sued the company in april seeking $ N ___
#
# million a for bond billion to N <eos> on up <unk> or an after monday in cents shares the had
# the suit named the company former chief executive officer william ___
#
# <unk> a N from <eos> of it with to at but on sell $ he well j. in an when
# the suit charged the defendants with causing peter e. <unk> ___
#
# <eos> the by and for of a to said losses is at with an inc. 's as <unk> between has
# mr. <unk> was previously sentenced to four years in prison ___
#
# <unk> with <eos> and the N as 's to that along which in by for $ inc taxes but its
# in the agreement recognition agreed to pay the government $ ___
#
# N <unk> n't the $ oct. is exchange time central not shares point one auto are its mortgage sept. half
# a trial on criminal allegations against the company and the ___
#
# <unk> issue dollar board company firm sale first department big new recent offer federal restructuring cost earnings s&p market acquisition
# they were indicted last october on charges of fraud theft ___
#
# <eos> the <unk> and inc. by said N which of to in ltd. co. a or has bond are 's
# in a related development recognition equipment said the postal service ___
#
# is 's which <unk> inc. have has division co. and corp. ended <eos> a will were was for of includes
# the postal service originally suspended the company oct. N N ___
#
# N and of <eos> to from shares for in on because at <unk> after with through despite three will would
# the company said it will continue to pursue a lifting ___
#
# of in <unk> <eos> $ for with test and or N loan that program by to amount offer debt exchange
# intel corp. reported a N N drop in third-quarter net ___
#
# income <unk> loss <eos> fell and to of was for as stock quarter rose said costs by saying worth in
# the big semiconductor and computer maker said it had net ___
#
# income <eos> <unk> of loss rose fell for and is a in worth inc. 's which to as services that
# the lower net included a charge of $ N million ___
#
# in from <eos> of <unk> for and or to a said loss compared on at which the 's by shares
# earning also fell from the year-ago period because of slowing ___
#
# <eos> <unk> the 's in work by that as customers its a activity already has and policy companies corp. which
# sales amounted to $ N million down N N from ___
#
# N a $ the its <unk> august nov. # three september july about last president an four some at year-earlier
# intel 's stock rose in early over-the-counter trading friday as ___
#
# a <unk> of the well part for far an many much they being at and to in had big low
# but intel later <unk> to the stock market 's plunge ___
#
# <unk> for $ and in price as value to high share by <eos> offer of record on bank or 's
# in august intel warned that third-quarter earnings might be flat ___
#
# to by the <unk> <eos> as its N in for into their first about it are if 's at only
# on friday andrew <unk> intel president and chief executive officer ___
#
# <eos> of have and <unk> will were the N a up said are compared would had for as new or
# our bookings improved as the quarter <unk> and september was ___
#
# <unk> <eos> n't a $ seeking as closed no an have seen expected the found that particularly made up not
# for the full quarter our bookings were higher than the ___
#
# <unk> fact N first dollar average new way treasury point report major short year the issue filing government big other
# for the nine-month period intel reported net of $ N ___
#
# million a billion or N <unk> shares of for up bond <eos> in the off to an and point common
# revenue amounted to $ N billion up slightly from $ ___
#
# N <unk> $ volume the n't computer oct. june sept. one stock exchange not time last five tuesday april <eos>
# after N years in prison mr. sisulu the <unk> former ___
#
# <unk> is a chief said and <eos> of for president has will the ' by was at trust who management
# at the same time six anc colleagues five of whom ___
#
# <unk> <eos> 's and of which for by the a in or management securities an concern said has national at
# and as the <unk> men returned to their homes the ___
#
# <unk> offer recent capital agency test new government joint exchange possible federal current board firm most fact trade big industry
# a huge anc flag with black green and gold <unk> ___
#
# <eos> <unk> for the of by has and did said 's a in have had which to are treasury is
# at the small <unk> home of <unk> <unk> a leading ___
#
# <unk> of a $ for the N <eos> that more and firm company in by stock earlier small futures or
# i am happy to see the spirit of the people ___
#
# <unk> would <eos> of who are ' group plan is were will was market do said industry have and mr.
# as the crowd outside his home shouted anc anc the ___
#
# <unk> government university agency loan recent european offer the future unit most industry new public program test top general $
# under the laws of the land the anc remains an ___
#
# additional <unk> interest expected $ estimated N increase old independent attorney the agreement average even auto office investor investment companies
# but the <unk> release of the seven leaders who once ___
#
# <unk> of called would to fell at <eos> in for a its and shares on market rose take are changes
# the government can never put the anc back into the ___
#
# <unk> dollar common community insurance test recent big issue loan end industry u.s. same public dow board offer market increase
# things have gone too far for the government to stop ___
#
# <unk> the its <eos> a and on in their to an as whether 's N such are for by customers
# there was certainly no <unk> the tide of anc <unk> ___
#
# <eos> and by <unk> inc. the of a said for co. in to which has or 's N university is
# <unk> <unk> of anc and <unk> we <unk> shook the ___
#
# <unk> fact government agency future new recent exchange company federal way growth most program the firm N loan offer proposed
# and they called on the government to release nelson <unk> ___
#
# <eos> the 's and <unk> by for of a said to in has as inc. with during at losses management
# without him said mr. sisulu the <unk> of the others ___
#
# of <eos> said was <unk> 's and to or by a will would can is in who which future may
# president <unk> de <unk> released the anc men along with ___
#
# a the mr. <unk> an first its it $ drexel his that by to all this any most <eos> long
# but pretoria may instead be creating a climate for more ___
#
# than <unk> the at and shares programs of projects for in important with earlier <eos> are investors $ efforts said
# as other <unk> governments particularly poland and the soviet union ___
#
# and of <eos> will are came <unk> on in after months since were much have a for that is last
# as the days go by the south african government will ___
#
# <unk> be continue cost hold provide take also become go are not fall the remain come generally likely move issue
# if it does n't yield on these matters and eventually ___
#
# <unk> the for <eos> of with are by a could as and in has national its an which about to
# if it does the large number of <unk> whites who ___
#
# had were are <unk> said did has the is have was programs at took a say business will ca and
# the newly released anc leaders also will be under enormous ___
#
# for <eos> of and <unk> in stock the by with a 's but to between rates are growth law or
# the government is watching closely to see if their presence ___
#
# <unk> to by for the in <eos> were are loans its especially with said j. creditors a treasury of N
# pretoria has n't forgotten why they were all sentenced to ___
#
# <unk> provide the N see be have meet reduce acquire a those go buy give do help increase allow find
# in addition the government is figuring that the releases could ___
#
# n't be <unk> have get still go make is become provide take were are continue also change to not result
# in order to head off any divisions mr. <unk> in ___
#
# a the <unk> his this los august new its london several april recent which late court future making each chicago
# the men also will be faced with <unk> the generation ___
#
# of <eos> <unk> the are with for and or by 's rate could has to government in was ' industry
# says peter <unk> president of the south african youth congress ___
#
# to the of <eos> by on with said <unk> and a about are since its he for at between an
# at last night 's rally they called on their <unk> ___
#
# <unk> the <eos> for to their in N its by with said and as management an back or $ have
# we <unk> discipline because we know that the government is ___
#
# <unk> n't a the not being expected also likely still too currently that in much <eos> very how no trying
# we want to see nelson <unk> and all our <unk> ___
#
# <unk> in the <eos> as a by its that and N 's $ to on of or about it &
