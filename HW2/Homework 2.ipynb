# %% [markdown]
# # HW 2: Language Modeling

# %% [markdown]
# In this homework you will be building several varieties of language models.
#
# ## Goal
#
# We ask that you construct the following models in PyTorch:
#
# 1. A trigram model with linear-interpolation. $$p(y_t | y_{1:t-1}) =  \alpha_1 p(y_t | y_{t-2}, y_{t-1}) + \alpha_2 p(y_t | y_{t-1}) + (1 - \alpha_1 - \alpha_2) p(y_t) $$
# 2. A neural network language model (consult *A Neural Probabilistic Language Model* http://www.jmlr.org/papers/volume3/bengio03a/bengio03a.pdf)
# 3. An LSTM language model (consult *Recurrent Neural Network Regularization*, https://arxiv.org/pdf/1409.2329.pdf)
# 4. Your own extensions to these models...
#
#
# Consult the papers provided for hyperparameters.

# %% [markdown]
# ## Setup
#
# This notebook provides a working definition of the setup of the problem itself. You may construct your models inline or use an external setup (preferred) to build your system.

# %%
# Text text processing library
import torchtext
from torchtext.vocab import Vectors

# %% [markdown]
# The dataset we will use of this problem is known as the Penn Treebank (http://aclweb.org/anthology/J93-2004). It is the most famous dataset in NLP and includes a large set of different types of annotations. We will be using it here in a simple case as just a language modeling dataset.

# %% [markdown]
# To start, `torchtext` requires that we define a mapping from the raw text data to featurized indices. These fields make it easy to map back and forth between readable data and math, which helps for debugging.

# %%
# Our input $x$
TEXT = torchtext.data.Field()

# %% [markdown]
# Next we input our data. Here we will use the first 10k sentences of the standard PTB language modeling split, and tell it the fields.

# %%
# Data distributed with the assignment
train, val, test = torchtext.datasets.LanguageModelingDataset.splits(
    path=".", 
    train="train.txt", validation="valid.txt", test="valid.txt", text_field=TEXT)

# %% [markdown]
# The data format for language modeling is strange. We pretend the entire corpus is one long sentence.

# %%
print('len(train)', len(train))

# %% [markdown]
# Here's the vocab itself. (This dataset has unk symbols already, but torchtext adds its own.)

# %%
TEXT.build_vocab(train)
print('len(TEXT.vocab)', len(TEXT.vocab))

# %% [markdown]
# When debugging you may want to use a smaller vocab size. This will run much faster.

# %%
if False:
    TEXT.build_vocab(train, max_size=1000)
    len(TEXT.vocab)

# %% [markdown]
# The batching is done in a strange way for language modeling. Each element of the batch consists of `bptt_len` words in order. This makes it easy to run recurrent models like RNNs.

# %%
train_iter, val_iter, test_iter = torchtext.data.BPTTIterator.splits(
    (train, val, test), batch_size=10, device=-1, bptt_len=32, repeat=False)

# %% [markdown]
# Here's what these batches look like. Each is a string of length 32. Sentences are ended with a special `<eos>` token.

# %%
it = iter(train_iter)
batch = next(it) 
print(vars(batch))
print("Size of text batch [max bptt length, batch size]", batch.text.size())
print("Second in batch", batch.text[:, 2])
print("Converted back to string: ", " ".join([TEXT.vocab.itos[i] for i in batch.text[:, 2].data]))

# %% [markdown]
# The next batch will be the continuation of the previous. This is helpful for running recurrent neural networks where you remember the current state when transitioning.

# %%
batch = next(it)
print("Converted back to string: ", " ".join([TEXT.vocab.itos[i] for i in batch.text[:, 2].data]))
print("Converted back to string: ", " ".join([TEXT.vocab.itos[i] for i in batch.text[:, 3].data]))
print("Converted back to string: ", " ".join([TEXT.vocab.itos[i] for i in batch.text[:, 4].data]))

# %% [markdown]
# There are no separate labels. But you can just use an offset `batch.text[1:]` to get the next word.

# %% [markdown]
# ## Assignment
#
# Now it is your turn to build the models described at the top of the assignment.
#
# Using the data given by this iterator, you should construct 3 different torch models that take in batch.text and produce a distribution over the next word.
#
# When a model is trained, use the following test function to produce predictions, and then upload to the kaggle competition: https://www.kaggle.com/c/cs287-hw2-s18

# %% [markdown]
# For the final Kaggle test, we will have you do a next word prediction task. We will provide a 10 word prefix of sentences, and it is your job to predict 10 possible next word candidates

# %%
# !head input.txt

# %% [markdown]
# As a sample Kaggle submission, let us build a simple unigram model.

# %%
from collections import Counter
count = Counter()
for b in iter(train_iter):
    count.update(b.text.view(-1).data.tolist())
count[TEXT.vocab.stoi["<eos>"]] = 0
predictions = [TEXT.vocab.itos[i] for i, c in count.most_common(20)]
print(predictions)
with open("sample.txt", "w") as fout: 
    print("id,word", file=fout)
    for i, l in enumerate(open("input.txt"), 1):
        print("%d,%s"%(i, " ".join(predictions)), file=fout)

# %%
# !head sample.txt

# %% [markdown]
# The metric we are using is mean average precision of your 20-best list.
#
# $$MAP@20 = \frac{1}{|D|} \sum_{u=1}^{|D|} \sum_{k=1}^{20} Precision(u, 1:k)$$
#
# Ideally we would use log-likelihood or ppl as discussed in class, but this is the best Kaggle gives us. This takes into account whether you got the right answer and how highly you ranked it.
#
# In particular, we ask that you do not game this metric. Please submit *exactly 20* unique predictions for each example.

# %% [markdown]
# As always you should put up a 5-6 page write-up following the template provided in the repository:  https://github.com/harvard-ml-courses/cs287-s18/blob/master/template/

# %% [markdown]
# # Neural Probabalistic Language Model

# %%
# Text text processing library
import torchtext
import torch
import math 
import torch.nn as nn 
from torchtext.vocab import Vectors
DEBUG = True 
# Our input $x$
TEXT = torchtext.data.Field()
# Data distributed with the assignment
train, val, test = torchtext.datasets.LanguageModelingDataset.splits(
    path=".", 
    train="train.txt", validation="valid.txt", test="valid.txt", text_field=TEXT)
TEXT.build_vocab(train)
print('len(TEXT.vocab)', len(TEXT.vocab))

if DEBUG == True:
    TEXT.build_vocab(train, max_size=1000)
    len(TEXT.vocab)
    print('len(TEXT.vocab)', len(TEXT.vocab))
    
train_iter, val_iter, test_iter = torchtext.data.BPTTIterator.splits(
    (train, val, test), batch_size=12, device=-1, bptt_len=32, repeat=False, shuffle=False)
# Out:
# len(TEXT.vocab) 10001
# len(TEXT.vocab) 1002

# %%
class NPLM(nn.Module):

    def __init__(self, V_vocab_dim, M_embed_dim, H_hidden_dim, N_seq_len):
        super(NPLM, self).__init__()
        self.vocab_size = V_vocab_dim
        self.embed = nn.Embedding(V_vocab_dim, M_embed_dim)
        self.hidden_linear = nn.Linear(M_embed_dim*N_seq_len, H_hidden_dim, bias=True)
        self.tanh_act = nn.Tanh()
        self.U_linear = nn.Linear(H_hidden_dim, V_vocab_dim, bias=True)
        self.W_linear = nn.Linear(M_embed_dim*N_seq_len, V_vocab_dim, bias=True)
        self.softmax = nn.LogSoftmax()

    def forward(self, x):
        x_embed = self.embed(x)
        print(x.shape)
        #print(x_embed.shape)
        x_flat = torch.autograd.Variable(torch.cat(x_embed.data, dim=1))
        #print(x_flat.shape)
        hidden_feat = self.hidden_linear(x_flat)
        #print(hidden_feat.shape)
        hidden_act = self.tanh_act(hidden_feat)
        #print(hidden_act.shape)
        hidden_out = self.U_linear(hidden_act)
        #print(hidden_out.shape)
        direct = self.W_linear(x_flat)
        #print(direct.shape)
        out = direct + hidden_out
        #print(out.shape)
        return self.softmax(out)

# %%
def evaluate(model, data_iterator):
    # Turn on evaluation mode which disables dropout.
    model.eval()
    total_loss = 0
    batch_count = 0 
    for batch in iter(data_iterator):
        for i in range(batch.text.size(0) - 5):
            output = model(batch.text[i:i+5])
            target = batch.target[i+5]
            total_loss += criterion(output, target).data
            batch_count += 1 
    return total_loss[0] / batch_count

def train_batch(model, criterion, optim, batch, label):
    # initialize hidden vectors
    model.zero_grad()
    # calculate forward pass
    y = model(batch)
    # calculate loss    
    loss = criterion(y, label)
    # backpropagate and step
    loss.backward()
    optim.step()
    return loss.data[0]

# training loop
def train(model, criterion, optim, data_iterator):

    for e in range(n_epochs):
        batches = 0
        epoch_loss = 0
        avg_loss = 0
        for batch in iter(data_iterator):
            for i in range(batch.text.size(0) - 5): 
                batch_loss = train_batch(model, criterion, optim, batch.text[i:i+5], batch.target[i+5])
                batches += 1
                epoch_loss += batch_loss
                avg_loss = ((avg_loss * (batches - 1)) + batch_loss) / batches
        print("Epoch ", e, " Loss: ", epoch_loss, "Perplexity: ", math.exp(avg_loss))
        loss = evaluate(model, val_iter)
        print("Epoch Val Loss: ", loss, "Perplexity: ", math.exp(loss)) 
        loss = evaluate(model, test_iter)
        print("Epoch Test Loss: ", loss, "Perplexity: ", math.exp(loss))

# size of the embeddings and vectors
n_embedding = 30
n_hidden = 60
seq_len = 5

# initialize LSTM
#npl = NPLM(len(TEXT.vocab), n_embedding, n_hidden, seq_len)

n_epochs = 10
learning_rate = .1
criterion = nn.NLLLoss()
optim = torch.optim.SGD(npl.parameters(), lr = learning_rate)


train(npl, criterion, optim, test_iter)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:29: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: DeprecationWarning: generator 'BPTTIterator.__iter__' raised StopIteration
# Epoch  0  Loss:  22673.985867977142 Perplexity:  79.34773217255078
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: generator 'BPTTIterator.__iter__' raised StopIteration
# Epoch Val Loss:  4.03994298864294 Perplexity:  56.82310315089835
# Epoch Test Loss:  4.03994298864294 Perplexity:  56.82310315089835
# Epoch  1  Loss:  21528.389946460724 Perplexity:  63.615235842668454
# Epoch Val Loss:  3.901693085093557 Perplexity:  49.486162502651055
# Epoch Test Loss:  3.901693085093557 Perplexity:  49.486162502651055
# Epoch  2  Loss:  20885.206489682198 Perplexity:  56.192433694483874
# Epoch Val Loss:  3.8063414773823303 Perplexity:  44.98555676089384
# Epoch Test Loss:  3.8063414773823303 Perplexity:  44.98555676089384
# Epoch  3  Loss:  20430.30175971985 Perplexity:  51.47161198226394
# Epoch Val Loss:  3.7365888430748457 Perplexity:  41.95463196198353
# Epoch Test Loss:  3.7365888430748457 Perplexity:  41.95463196198353
# Epoch  4  Loss:  20079.03037214279 Perplexity:  48.09940214962427
# Epoch Val Loss:  3.681728033371914 Perplexity:  39.71496359275268
# Epoch Test Loss:  3.681728033371914 Perplexity:  39.71496359275268
# Epoch  5  Loss:  19793.89736711979 Perplexity:  45.52525555139253
# Epoch Val Loss:  3.636548077618634 Perplexity:  37.96057334749726
# Epoch Test Loss:  3.636548077618634 Perplexity:  37.96057334749726
# Epoch  6  Loss:  19553.442842006683 Perplexity:  43.46183793825939
# Epoch Val Loss:  3.5979075490692516 Perplexity:  36.52173449805574
# Epoch Test Loss:  3.5979075490692516 Perplexity:  36.52173449805574
# Epoch  7  Loss:  19345.226205468178 Perplexity:  41.75077516830986
# Epoch Val Loss:  3.564491931303048 Perplexity:  35.321503094618926
# Epoch Test Loss:  3.564491931303048 Perplexity:  35.321503094618926
# Epoch  8  Loss:  19161.713376522064 Perplexity:  40.298657944280684
# Epoch Val Loss:  3.5356761791087963 Perplexity:  34.318212128634116
# Epoch Test Loss:  3.5356761791087963 Perplexity:  34.318212128634116
# Epoch  9  Loss:  18998.04245531559 Perplexity:  39.04621107321825
# Epoch Val Loss:  3.5104599940923995 Perplexity:  33.46365732880502
# Epoch Test Loss:  3.5104599940923995 Perplexity:  33.46365732880502

# %%
with open("sample.txt", "w") as fout: 
    print("id,word", file=fout)
    for i, l in enumerate(open("input.txt"), 1):
        print(l)
        input_tokens = l.split(" ")[-6:-1]
        input_index = torch.LongTensor([TEXT.vocab.stoi[t] for t in input_tokens]).unsqueeze(1)
        output = npl(torch.autograd.Variable(input_index))
        max_values, max_indices = torch.topk(output, 20)
        print(" ".join([TEXT.vocab.itos[int(i)] for i in max_indices.data[0, :]]))
        
        #print("%d,%s"%(i, " ".join(predictions)), file=fout)
# Out:
# but while the new york stock exchange did n't fall ___
#
# market says <eos> <unk> to august it of new that steel in mr. a 's six was meanwhile he N
# some circuit breakers installed after the october N crash failed ___
#
# and financing N <unk> <eos> rose from had in mr. is its yet make 's did earnings year to index
# the N stock specialist firms on the big board floor ___
#
# many <unk> a firms <eos> its will and he the to company risk N general their they by in j.
# big investment banks refused to step up to the plate ___
#
# he <unk> <eos> new the secretary that is in late a as now to they n't then have such de
# heavy selling of standard & poor 's 500-stock index futures ___
#
# closed <unk> the that have still a $ N plans line points to n't commission debt much be yet out
# seven big board stocks ual amr bankamerica walt disney capital ___
#
# and in <unk> <eos> british director chairman is mr. soviet says under it are the of james management to does
# once again the specialists were not able to handle the ___
#
# <eos> on market <unk> of to said was and in a but around the 's de it morgan he by
# <unk> james <unk> chairman of specialists henderson brothers inc. it ___
#
# <unk> for be <eos> n't to keep possible and N of new have by billion my a hard offering the
# when the dollar is in a <unk> even central banks ___
#
# <unk> <eos> to when bank N n't it at a their the in he or sell that day of up
# speculators are calling for a degree of liquidity that is ___
#
# <unk> to in with that new means for N big and a anything is it been 's at major standard
# many money managers and some traders had already left their ___
#
# <unk> to <eos> closed before the with they of managers funds in on see for at only and & mr.
# then in a <unk> plunge the dow jones industrials in ___
#
# u.s. and 's N out <eos> of says in oct. to <unk> first loan markets from the left bank yesterday
# <unk> trading accelerated to N million shares a record for ___
#
# companies company N <eos> <unk> $ conference bid average in outside securities that the 's would its after some fourth
# at the end of the day N million shares were ___
#
# august <unk> in earlier common because $ N the his income to were rules weeks shearson a of is being
# the dow 's decline was second in point terms only ___
#
# with <eos> <unk> to if 's every agreement the and of said there by china but operations unit out itself
# in percentage terms however the dow 's dive was the ___
#
# of 's <eos> half was and <unk> something says company two had for up the closed in trading year market
# shares of ual the parent of united airlines were extremely ___
#
# the <unk> transportation make had is for a in first and both who little would but offer most director co.
# wall street 's takeover-stock speculators or risk arbitragers had placed ___
#
# N last <unk> in he of <eos> firms have a to the for company its here we $ and both
# at N p.m. edt came the <unk> news the big ___
#
# be <unk> <eos> and to chairman school says 's the institute senate for in failed official this because been on
# on the exchange floor as soon as ual stopped trading ___
#
# <unk> to the N 's big at says <eos> a after long and in as it ual its an yesterday
# several traders could be seen shaking their heads when the ___
#
# is <eos> 's was to of monday said with <unk> for says the customers average and in banks market would
# for weeks the market had been nervous about takeovers after ___
#
# up <unk> it and <eos> seven as activity the high 's N after days all back if before head its
# and N minutes after the ual trading halt came news ___
#
# <unk> traders <eos> that N trading to the financial market his investments of banking gains hold he like for on
# arbitragers could n't dump their ual stock but they rid ___
#
# <unk> to <eos> are of the N market in or been his with costs they a gain three its it
# for example their selling caused trading halts to be declared ___
#
# the research <unk> <eos> very operations company he to been as service before and agreement were debt by expected first
# but as panic spread speculators began to sell blue-chip stocks ___
#
# the when <eos> in could <unk> higher charge are heavy and earnings caused issues a N for have named or
# when trading was halted in philip morris the stock was ___
#
# <unk> is have and has N <eos> to he took it in little new most its the n't were which
# selling <unk> because of waves of automatic stop-loss orders which ___
#
# including <unk> and in co that have at to <eos> the he it earnings heavy get calls national sale need
# most of the stock selling pressure came from wall street ___
#
# <unk> n't <eos> a to the it pay can with spending says N we if now america that mr. $
# traders said most of their major institutional investors on the ___
#
# <eos> world of institute in was is 's office to N <unk> lines and but issues market from says many
# now at N one of the market 's post-crash reforms ___
#
# <eos> and ended <unk> the can he of a into volatility by to black fell in that but currently bill
# under an agreement signed by the big board and the ___
#
# <eos> <unk> of was a for quarter to says is has units major N market company stocks in nation he
# after the trading halt in the s&p N pit in ___
#
# <eos> and <unk> three from first the dow recent to N into markets their for year it of a in
# as a result the link between the futures and stock ___
#
# futures <eos> make N to <unk> in after a at had will it company place subsidiary stock-index included and on
# without the <unk> of stock-index futures the barometer of where ___
#
# <unk> <eos> congress to in ago will and its the are at name a or be steel N black have
# the futures halt was even <unk> by big board floor ___
#
# people report even lot and secretary general <eos> higher hong perhaps a this <unk> service new inc. the office power
# this confusion effectively halted one form of program trading stock ___
#
# <unk> N an $ to government a more look <eos> federal 's in whether all and had significant remains found
# in a stock-index arbitrage sell program traders buy or sell ___
#
# companies n't <eos> stock drop corporate sale <unk> dropped a they lower short-term was of the making earnings systems noted
# when the airline information came through it <unk> every model ___
#
# he <unk> we china the some to a two of james right but market <eos> three that first with why
# we did n't even get a chance to do the ___
#
# <eos> of nation <unk> from has on in year special and spending first stocks market says officials to technology out
# the dow industrials were down N points at N p.m. ___
#
# <eos> N that the <unk> who volume have they was a he or points $ of by on to in
# at N p.m. at the end of the cooling off ___
#
# <unk> orders <eos> to it $ N for is and in because a employees my that mr. people assets he
# meanwhile during the the s&p trading halt s&p futures sell ___
#
# <unk> with the N million a before $ <eos> to he their year as they it for during in is
# big board chairman john j. phelan said yesterday the circuit ___
#
# <eos> that <unk> attorney is a and in today such during said be who have friday which N to the
# i just think it 's <unk> at this point to ___
#
# <unk> <eos> the N manufacturing and n't yesterday more they its one a trading any 's of is years he
# under another post-crash system big board president richard <unk> mr. ___
#
# says <unk> <eos> 's would and exchange who in ltd. to which i the reports association sales of was mr.
# he <unk> out at a high-tech <unk> center on the ___
#
# is board <unk> <eos> market to and in decline of said down was 's because debt N but talks from
# at about N p.m. edt s&p futures resumed trading and ___
#
# <unk> ' a in traders as gas trade interest <eos> have would the that and bid more was to fees
# but the <unk> of s&p futures sell orders weighed on ___
#
# <unk> to that <eos> in market friday so chief demand certain without back N orders according the $ but it
# at about N the s&p market <unk> to still another ___
#
# <eos> might <unk> into N no years to as when is by the must it may wo major investors oct.
# futures traders say the s&p was <unk> that the dow ___
#
# N is industrial bid did of to <eos> the 's treasury market that in and index it trading <unk> fell
# during this time small investors began ringing their brokers wondering ___
#
# <unk> higher the and heavy any N <eos> says to by as them in mr. for has early yesterday a
# at prudential-bache securities inc. which is trying to cater to ___
#
# the into their <unk> around <eos> and its economic west on to reserves a three out how 's parent it
# that 's when george l. ball chairman of the prudential ___
#
# and department that a division new does he u.s. <eos> company there is contracts have already major the has ltd.
# i have a <unk> that this particular decline today is ___
#
# <unk> it in be <eos> by biggest on new and get N as a for than mr. was often prices
# it would be my <unk> to advise clients not to ___
#
# 's N <eos> <unk> west the a big this it he most says and its to much could major reserves
# at merrill lynch & co. the nation 's biggest brokerage ___
#
# <unk> and <eos> the to unit first N in that was year a says european were it trading $ francisco
# the release cautioned that there are significant differences between the ___
#
# <unk> of and <eos> says 's said a market to that N for bay would is in were among the
# however jeffrey b. lane president of shearson lehman hutton inc. ___
#
# says in <unk> N set for and before from a it the ever <eos> its western & co. capital that
# and i think a lot of people will <unk> on ___
#
# N <unk> a the it that soviet line <eos> and mr. in dollars pay monday sale months market back day
# it 's going to bring the debate right back to ___
#
# <eos> and <unk> N it n't says cents out to this 's on at them sales their yesterday in way
# as the dow average ground to its final N loss ___
#
# <unk> tokyo $ mr. n't this its loans a director before index two been more employees year the in and
# jeffrey <unk> of program trader <unk> investment group said N ___
#
# N from <unk> shares was a mr. the u.s. in were <eos> that general less to and already its new
# while friday 's debacle involved mainly professional traders rather than ___
#
# <unk> N small magazine chairman it years big <eos> and large to for the their any as like at two
# stock-index futures contracts settled at much lower prices than indexes ___
#
# <unk> making huge itself in of on john banks at <eos> four N and that year is the public far
# at those levels stocks are set up to be <unk> ___
#
# <eos> <unk> the to we been a such have that said he this its than first in it us of
# but nobody knows at what level the futures and stocks ___
#
# N <eos> addition to n't a <unk> its futures u.s. advertising he said new down by one contracts have with
# the <unk> between the stock and futures markets friday will ___
#
# <unk> <eos> production in that buy ' is used it market n't york one cents sales nation demand to says
# the big board 's mr. <unk> said our <unk> performance ___
#
# it systems <eos> <unk> stock in and back N increased international 's went than the their for that were was
# but the exchange will look at the performance of all ___
#
# <eos> major <unk> history black be international the have it up to by white plan free new buying because but
# obviously we 'll take a close look at any situation ___
#
# <eos> in had have before to N business <unk> a and that he after the of it would about $
# see related story fed ready to <unk> big funds wsj ___
#
# vice he <unk> <eos> to chief its says but the 's and is this in with be do reserves we
# but specialists complain privately that just as in the N ___
#
# <eos> he and in a to <unk> later of gain mr. N index trading did said up that years its
# mr. phelan said it will take another day or two ___
#
# ago to <eos> a stocks is ' in rates <unk> and point yet they N based so have out was
# concerning your sept. N page-one article on prince charles and ___
#
# <unk> in and to <eos> the executives N according were a university many who marketing executive few banks coming '
# it 's now the united kingdom of great britain and ___
#
# firm <unk> for a best N the house but by air from new just executive in which u.s. or operations
# ports of call inc. reached agreements to sell its remaining ___
#
# <eos> the <unk> in of and earnings have a N if for selling that its but it is prices from
# the agreements bring to a total of nine the number ___
#
# morgan <unk> N american compared a firms the <eos> concern year to board said makes strong on expected for in
# the company said a portion of the $ N million ___
#
# <eos> in loan have N $ fiscal the n't <unk> a it was union year net by is operating for
# earlier the company announced it would sell its aging fleet ___
#
# <unk> to <eos> up and he the other they are by a that it have for their from mr. been
# a consortium of private investors operating as <unk> funding co. ___
#
# that <unk> some and city the $ up over to its for it then of last get a only in
# the $ N million bid includes the assumption of an ___
#
# <eos> <unk> major N computer at deal buying in to that management will and stock-index of the futures is many
# the group is led by jay <unk> chief executive officer ___
#
# <unk> <eos> in to from month up it 's and believe a but may N came the that director after
# mr. <unk> 's company specializes in commercial real-estate investment and ___
#
# <unk> N to and <eos> two a growing in because executive few the systems national equipment takeover strong is stock
# the assets are good but they require more money and ___
#
# a N it is to <unk> had <eos> in many strong and are prices the national operations will he transportation
# l.j. hooker based in atlanta is operating with protection from ___
#
# <unk> of purchase before subsidiary and the however sale by exchange <eos> earnings $ only that an share year N
# its parent company hooker corp. of sydney australia is currently ___
#
# <unk> inc. sale chairman it maker if N food says be is and securities a director in than co <eos>
# sanford <unk> chief executive of l.j. hooker said yesterday in ___
#
# and <unk> N is the <eos> stock from prices a at year big columbia trading statement could much are first
# the $ N million bid is estimated by mr. simpson ___
#
# <unk> groups <eos> and in its to the still a any high some data all it debt last sold international
# not included in the bid are <unk> teller or b. ___
#
# <unk> is to says and would had co. a <eos> just have chief it n't the in he some 's
# the offer covers the massive N <unk> forest fair mall ___
#
# <eos> and president world 's marketing N <unk> the chairman its in other cents of joint $ for april has
# the <unk> mall opened sept. N with a <unk> 's ___
#
# <eos> and in <unk> of 's was futures stock to N for program market would loans began york the at
# other hooker properties included are a <unk> office tower in ___
#
# N it <eos> with says of is and york some u.s. <unk> 's company into by the to prices an
# the consortium was put together by <unk> <unk> the london-based ___
#
# <eos> and their <unk> for a its which offer says life higher to agency in mr. who national as has
# we do n't anticipate any problems in raising the funding ___
#
# <eos> its of president in <unk> china and years a trading has other would business he right deal N that
# according to people familiar with the consortium the bid was ___
#
# <unk> <eos> subject have ual he do might financial is to corp. must according black had can mr. would was
# l.j. hooker was a small <unk> company based in atlanta ___
#
# <unk> <eos> and in is who had without the even that to calif. sales chairman for recently ' adds plans
# the company grew modestly until N when a majority position ___
#
# <unk> company in a the <eos> at and that but N for before of was 're all with as made
# mr. <unk> <unk> to launch an ambitious but <unk> $ ___
#
# million <unk> <eos> set and a chairman ca should in the been at are to yesterday billion n't be says
# eventually mr. simpson and mr. <unk> had a falling out ___
#
# for to <unk> about and the point in a that <eos> he maker up it its his time months mr.
# since then hooker corp. has sold its interest in the ___
#
# <unk> <eos> market which was futures to would after as he is for losses and group of previously a N
# in addition robert <unk> chief executive of the <unk> chain ___
#
# <unk> a economic area he <eos> new remain in technology is your to they and done market president from the
# the merksamer chain is currently being offered for sale by ___
#
# really you ual <unk> banks <eos> commercial would company been than off end 's the three is n't called fiscal
# reached in <unk> mr. <unk> said that he believes the ___
#
# market <eos> million charge of <unk> is was futures to a but 's and debt time would for group in
# these are n't mature assets but they have the potential ___
#
# near <eos> shares saying in a to go was there that said you those $ <unk> friday subject n't for
# managed properly and with a long-term outlook these can become ___
#
# <unk> be analysts the day 'll said was life its <eos> is who their corp. use say believe within he
# canadian <unk> production totaled N metric tons in the week ___
#
# <unk> to is N now price <eos> black in that while which before big 's just and new be investors
# the week 's total was up N N from N ___
#
# a <eos> in and <unk> four on year to according it or but yen close from friday times earlier lower
# the <unk> total was N tons up N N from ___
#
# N <eos> year to <unk> back share the for and this its a then 's we yen in billion including
# the treasury plans to raise $ N million in new ___
#
# <unk> <eos> and stock by a seems that on in much the you of yesterday during to but earlier filing
# the bills will be dated oct. N and will mature ___
#
# <unk> <eos> to might a in it three sell will half $ N and is by he but when co.
# bids must be received by N p.m. edt thursday at ___
#
# and <unk> N executive of 's life <eos> almost years the he three terms street there statement do time marketing
# as small investors <unk> their mutual funds with phone calls ___
#
# <unk> is prices and director that which in corp. it he its been working weeks under <eos> yesterday a about
# unlike the weekend before black monday the funds were n't ___
#
# <unk> <eos> the much a N and to them $ on at with had by in of it mr. points
# and many fund managers have built up cash levels and ___
#
# <unk> chairman according u.s. development officials new N made energy into weeks a american quarter third have their all ad
# at fidelity investments the nation 's largest fund company telephone ___
#
# <unk> to net a was been $ the he figures is their were its at say international earnings product said
# the boston firm said <unk> redemptions were running at less ___
#
# very higher to and another have <eos> 's down they at says be <unk> a about today was years up
# as of yesterday afternoon the redemptions represented less than N ___
#
# makers and in a drop <eos> shares from at on losses ended the is its bid hours of one build
# two years ago there were massive redemption levels over the ___
#
# is <eos> <unk> and 's was added market price to he in prices financial a buying only quarter trust board
# friday 's stock market sell-off came too late for many ___
#
# <eos> but <unk> loss october said who to such fall in hit the N was san of york been ago
# some shareholders have held off until today because any fund ___
#
# <unk> assets week $ in higher would the even corp. <eos> n't up they from revenue with shares says march
# stock fund redemptions during the N debacle did n't begin ___
#
# world <eos> 's loan was <unk> firm N market wo view office charge and but is what came cents to
# many have raised cash levels which act as a buffer ___
#
# <unk> that <eos> of at the a company to who being it was and effect research in growth for insurance
# mario <unk> for instance holds cash positions well above N ___
#
# N in and the <eos> <unk> $ of higher a to should price its own old last 's chairman for
# windsor fund 's john <unk> and mutual series ' michael ___
#
# away million <eos> <unk> at and with the rise united today firm value N you by a in to tokyo
# even peter lynch manager of fidelity 's $ N billion ___
#
# <unk> the <eos> share a in low those have bond $ back N once last new annual for is its
# one reason is that after two years of monthly net ___
#
# and <unk> those <eos> 's N yesterday spokesman friday to a mr. in of the capital air much down $
# i 've let the money build up mr. lynch said ___
#
# <unk> at <eos> such a that to N said it he the 's gain made close they subsidiary in equity
# as a group stock funds held N N of assets ___
#
# expected N operating <unk> & say the <eos> from to 's year down $ million and prices cents on dow
# that was modestly higher than the N N and N ___
#
# <eos> a from to and <unk> ended its year net is advanced N in average been it due had high
# also persistent redemptions would force some fund managers to dump ___
#
# <unk> market total a of order he morgan run while <eos> purchase 's new brokers mr. dow loan orders in
# but a strong level of investor withdrawals is much more ___
#
# <unk> turned union him is a market and more N to past international in construction company <eos> new $ this
# a major reason is that investors already have sharply scaled ___
#
# <unk> the a <eos> and his to want that in an total inc lot because back it at members used
# <unk> sales have rebounded in recent months but monthly net ___
#
# <unk> in the as to back years it of their turned a N instead for and or <eos> at be
# there 's not nearly as much <unk> said john <unk> ___
#
# remain could <unk> three that years in chairman costs and still is which 's be to call N of high
# many fund managers argue that now 's the time to ___
#
# <unk> <eos> it even they n't 's company into the a held maker said up people and N have one
# vincent <unk> manager of the $ N billion wellington fund ___
#
# in <unk> and <eos> ltd. year say that to the N most been it from but because $ he airlines
# and today he 'll be looking to buy drug stocks ___
#
# the <unk> <eos> in after ual assets and a its have from companies not friday at see for off lot
# fidelity 's mr. lynch for his part snapped up southern ___
#
# <unk> in N to china a that the <eos> investors are last would and spokesman as has rules dollar companies
# if the market drops further today he said he 'll ___
#
# take back in <unk> they return <eos> but added as at issues was the funds were some of will has
# if they <unk> stocks like that he said it presents ___
#
# <unk> in the buy remain a agreement at first and estimates on to their reserves analysts as if will director
# major mutual-fund groups said phone calls were <unk> at twice ___
#
# its london higher 's after <unk> a and at for to of all up perhaps high another the this <eos>
# they hope to avoid the <unk> phone lines and other ___
#
# <unk> <eos> N and been 's that last in of the for from a it other said one where mr.
# fidelity on saturday opened its N <unk> investor centers across ___
#
# and the <eos> of $ <unk> chairman 's who called executive N in president april today capital been set statement
# in addition east coast centers will open at N edt ___
#
# <eos> <unk> too his black closed to of that their a N he as the some but it year index
# t. rowe price associates inc. increased its staff of phone ___
#
# <unk> the co. that N could <eos> steel office estate and is a to in $ as much be of
# the <unk> group noted that some investors moved money from ___
#
# <unk> that economy i under <eos> the N in to back for is market others sale soviet a with are
# but most investors seemed to be in an information mode ___
#
# <unk> <eos> new the n't by in and its $ they says through is of august a company early but
# and vanguard among other groups said it was adding more ___
#
# N he was half from said <unk> 's a to were been the new started market corp. for is in
# in an unusual move several funds moved to calm investors ___
#
# to have <unk> <eos> and its a it he their debt the n't around is mr. not market rather like
# we view friday 's market decline as offering us a ___
#
# <unk> <eos> price any by of nation might more after rise long loss october than in years addition to on
# several fund managers expect a rough market this morning before ___
#
# <eos> N him was contracts the some <unk> billion is to about 's it can outside especially black and million
# some early selling is likely to stem from investors and ___
#
# believe <unk> york units many <eos> deficit airline executive firm local these securities N he strong up problems number officials
# stock funds have averaged a staggering gain of N N ___
#
# <eos> and a in close including N year its for sept. to <unk> point share that another at so showed
# <unk> <unk> who runs shearson lehman hutton inc. 's $ ___
#
# million <eos> <unk> billion and now a but yesterday is N of in as n't the to at much issues
# but she expects prices to rebound soon and is telling ___
#
# <eos> is the <unk> have and new a n't to other it N in much among that industry are was
# nevertheless ms. <unk> said she was <unk> with phone calls ___
#
# and he <unk> it 's is <eos> its that the a said been no about their corp. an have tokyo
# half of them are really scared and want to sell ___
#
# N <eos> <unk> in from on information they brokers when but that to and would company mr. majority for trust
# she added if they all were bullish i 'd really ___
#
# <unk> change and expected so been <eos> in all is the prices of new market to 's world trade N
# the backdrop to friday 's slide was <unk> different from ___
#
# <unk> sale N and that for major <eos> is to previous have the be 's a markets on fact its
# two years ago unlike today the dollar was weak interest ___
#
# yet <eos> and his their in <unk> small last to chairman that they it he of N for the says
# from the investors ' standpoint institutions and individuals learned a ___
#
# in started of <unk> <eos> bank on great food that 've ad would N last loan april and plant it
# this time i do n't think we 'll get a ___
#
# <unk> we at <eos> money offering for like of N to mr. in offer with that prices since a last
# newport corp. said it expects to report <unk> earnings of ___
#
# <unk> in N banks sales <eos> before for cents futures year by with around a acquisition that be market drop
# the maker of scientific instruments and laser parts said orders ___
#
# <eos> the to options <unk> was that N some it major and in by a continue he 's from of
# a spokesman added that sales in the current quarter will ___
#
# <eos> N down to cents has a buyers n't have on futures gain its <unk> two about in motor mr.
# <unk> from the strike by N machinists union members against ___
#
# N <eos> before <unk> three firm during shares and of by recent in dow last mr. the dollar earlier $
# peter <unk> vice president for planning at the phoenix ariz. ___
#
# and <unk> <eos> is the executives in your steel reduced N he set maker estimated based business sold of technology
# mr. <unk> said boeing told america west that the N ___
#
# <eos> decline to was a in N that said of market stocks index close or $ it with drop on
# boeing is also supposed to send to america west another ___
#
# <eos> marketing the drop N <unk> in away with a richard for take and still after $ so when we
# at this point no other america west flights including its ___
#
# <unk> to that and revenue british much the shares <eos> said form in but major fall get are business for
# nevertheless the company 's reaction <unk> the <unk> effect that ___
#
# n't <unk> is could he that my would it was years N says the has reported she in <eos> and
# it also is sure to help the machinists put added ___
#
# <eos> <unk> in to would at major for that with share much and most N loan exchange included on rally
# i just do n't feel that the company can really ___
#
# come <eos> <unk> will after during to buying prices in was had there his the rose he best said of
# i do n't think their customers would like it very ___
#
# <unk> the in york that at expected just on a of workers <eos> company year says during whose today among
# america west though is a smaller airline and therefore more ___
#
# is N <unk> in <eos> to half bought it new a long was have showed says will n't started said
# i figure that american and united probably have such a ___
#
# of <unk> N our the by would in york price a conference at ago on and program with almost board
# indeed a random check friday did n't seem to indicate ___
#
# they on <unk> that with up <eos> who mr. the company in says a and at N accounts its only
# southwest airlines has a boeing N set for delivery at ___
#
# N <eos> year of years point 's low <unk> late and the time board down many three same it lynch
# it 's so close to completion boeing 's told us ___
#
# is <eos> too <unk> of and in to says executive say six from it had one N he given was
# a spokesman for amr corp. said boeing has assured american ___
#
# soviet two until <unk> deal how ual never and the an previously both was to <eos> vice contracts one number
# american is preparing to take delivery of another N in ___
#
# N weeks <unk> almost <eos> quarter ad the for years financial to more three from previous early prices 's when
# in seattle a boeing spokesman explained that the company has ___
#
# <unk> <eos> was a potential is have last earnings that the issues yet had when and even to problems big
# meanwhile supervisors and <unk> employees have been trying to finish ___
#
# <unk> several would a in market that the least as ' robert they have some new legislation mr. i <eos>
# as of friday four had been delivered and a fifth ___
#
# <eos> of its in N is profit china and up a at the an might <unk> meeting over health managers
# no date has yet been set to get back to ___
#
# <unk> <eos> if and stock out N yen their would offer a it as market the october york n't cents
# we want to make sure they know what they want ___
#
# N in <unk> for to shearson and during amount shares of the that on ad did old this are it
# the investment community for one has been anticipating a <unk> ___
#
# strategy the <unk> of be expected a department to such he on with and is its <eos> some who china
# though boeing 's stock price was battered along with the ___
#
# and <eos> 's <unk> of is market six most time at maker up said however had value N through a
# the market has taken two views that the labor situation ___
#
# <unk> <eos> that and ' is to have N members of in because would year will first futures keep based
# boeing 's shares fell $ N friday to close at ___
#
# <unk> N the and year from including <eos> same income as but price on to a debt have it of
# but mr. baker said he thinks the earliest a pact ___
#
# <eos> the is steel and that of it its <unk> to for in on with says year selling by a
# still he said it 's possible that the strike could ___
#
# <unk> back some so a <eos> government the in and health sept. have groups four they market stocks little through
# last week boeing chairman frank <unk> sent striking workers a ___
#
# and N <unk> marketing agency <eos> that product last in is food of for to loss spokesman it maker technology
# but mr. baker called the letter and the company 's ___
#
# <unk> <eos> N would and to is in business from office also but will has had any its rose them
# he added that the company <unk> the union 's resolve ___
#
# <eos> N also <unk> is the during to have in he n't are and without it mr. its firm cents
# in separate developments talks have broken off between machinists representatives ___
#
# <eos> <unk> and the loan in by give to chairman its they inc state a from who of contracts co
# the union is continuing to work through its expired contract ___
#
# <unk> million about <eos> the a with says and as for debt its annual to some previously this up N
# it had planned a strike vote for next sunday but ___
#
# issues operating take <unk> <eos> in N become reported it the are for $ year to research that each buy
# united auto workers local N which represents N workers at ___
#
# <unk> and <eos> N the of by do are for on end from if up year to it almost week
# and boeing on friday said it received an order from ___
#
# <eos> said <unk> sale to loan 's N on offering an stock market but the selling it that a at
# the planes long range versions of the <unk> <unk> will ___
#
# used in <eos> it says <unk> could N fell the its two so years n't production for capital that is
# a boeing spokeswoman said a delivery date for the planes ___
#
# <eos> which is says such it to N american up <unk> and out had a has the in who year
# <unk> ltd. said its utilities arm is considering building new ___
#
# for that <unk> and of in to commercial buy by <eos> taken many the ever a it north san N
# <unk> <unk> <unk> 's senior vice president finance said its ___
#
# <eos> <unk> profit to said estate the despite working in and used continue of gain that it at annual with
# but we would n't go into them alone and canadian ___
#
# <eos> <unk> to executives for $ important of president agreed in at it its the then my high basis large
# <unk> we 'd like to be the operator of the ___
#
# <eos> is world states to agreement deal and name of market contract <unk> technology N in that was people loan
# our long suit is our proven ability to operate power ___
#
# and <unk> is domestic <eos> the by it which groups marketing in talks commercial many u.s. year to division but
# mr. <unk> would n't offer <unk> regarding <unk> 's proposed ___
#
# <eos> <unk> is the and N to that loss board in n't rather it he of $ by its was
# britain 's government plans to raise about # N billion ___
#
# <unk> the high a good trading from and N in this with of that <eos> as so its for or
# the planned electric utility sale scheduled for next year is ___
#
# <unk> 's up and N in it to <eos> as for of largely he said at north nov. news firms
# under terms of the plan independent <unk> would be able ___
#
# in <eos> <unk> says like of concern by mr. the too late situation stake six N to an order rep.
# canadian utilities had N revenue of c$ N billion mainly ___
#
# N the and is <unk> <eos> inc. a rate 's have of director they by from but in national with
# there seems to be a move around the world to ___
#
# <unk> its a steel into the of around markets <eos> N better advertising from you and it capital foreign over
# this is a real thrust on our utility side he ___
#
# <eos> <unk> and its executive high the through lead he said have reduce soon it an bank a N government
# canadian utilities is n't alone in exploring power generation opportunities ___
#
# <eos> its a up and executive from they american he have <unk> james in trading chief year black mr. recently
# we 're certainly looking at some power generating projects in ___
#
# <unk> N recent u.s. in is to <eos> for and trading at 's their this declined when loans would of
# mr. <unk> said enron is considering building <unk> power plants ___
#
# <unk> did is months a no to cost will could name says being sold prices in other lead of may
# pse inc. said it expects to report third earnings of ___
#
# N <unk> in street futures <eos> sales the he before year company for we that market $ traders two drop
# in the year-ago quarter the designer and operator of <unk> ___
#
# N <unk> <eos> is from countries performance and to the in its network but that industrial are a agency delivery
# the company said the improvement is related to additional <unk> ___
#
# <unk> the that and of <eos> from to over little john business in a being as during after should he
# <unk> <unk> flights are $ N to paris and $ ___
#
# million billion <unk> a did <eos> N the at for in were other and made bid he had of both
# in a centennial journal article oct. N the fares were ___
#
# <unk> in a $ but from and <eos> to an his the by of disclosed N they mr. on as
# diamond <unk> offshore partners said it had discovered gas offshore ___
#
# <eos> its a in <unk> later and the it N says up at which of made but to his be
# the well <unk> at a rate of N million cubic ___
#
# <unk> compared on N a from <eos> the to this up just been said it with had mr. by is
# diamond <unk> is the operator with a N N interest ___
#
# N the year <unk> net <eos> $ this earnings third-quarter a that is had on contract charge an in by
# diamond <unk> offshore 's stock rose N cents friday to ___
#
# a <unk> <eos> on from in N to they company out 's the board value one up yesterday or n't
# <unk> & broad home corp. said it formed a $ ___
#
# million a billion with the <eos> <unk> of was n't for to be is an almost note offer he need
# the partnership <unk> & broad land development venture limited partnership ___
#
# <unk> american the <eos> N well buy in shares who inc rules net within officials ford during air with of
# <unk> & broad a home building company declined to identify ___
#
# <unk> steel of in <eos> the with further their mr. that and it reason to a news sales heavy as
# the land to be purchased by the joint venture has ___
#
# N <unk> <eos> million the a new it with prices to and reserves exchange he was even back many service
# the partnership runs the risk that it may not get ___
#
# <unk> the N <eos> to but a according in expected prices is said it big against from that was same
# there are really very few companies that have adequate capital ___
#
# and of in to the <eos> a <unk> with mr. it that but work very at according N all unit
# typically developers option property and then once they get the ___
#
# <eos> <unk> price N of time auction to in and market between is was as major law 's a mr.
# by setting up the joint venture <unk> & broad can ___
#
# research <unk> 's the <eos> N to a. $ west its number said generally is and white disclosed he holdings
# the company is putting up only N N of the ___
#
# <eos> 's is <unk> market and N management to maker ltd. reported ended first off loan says venture employees are
# this is one of the best ways to assure a ___
#
# earlier analyst <unk> on york until to N that and their from price <eos> without of up the period said
# when the price of plastics took off in N quantum ___
#
# he its chairman we that the a first <unk> have through N but from sales <eos> then to it 's
# the timing of quantum 's chief executive officer john <unk> ___
#
# banks that even union a made <unk> the you <eos> with sept. first analyst never market many of increases biggest
# the company <unk> much of the chemical industry as annual ___
#
# <eos> the of N <unk> yesterday to year transportation and in for make than news with dropped this a says
# mr. <unk> said of the boom it 's going to ___
#
# <unk> the is <eos> he that united a out for and its N much other on 's an into said
# but now prices have <unk> and quantum 's profit is ___
#
# <eos> and <unk> it to said N 's calls line in the by an up all a last thing from
# some securities analysts are looking for no better than break-even ___
#
# <eos> the estimate and far by include has a four first year in workers <unk> of posted where at shares
# the stock having lost nearly a quarter of its value ___
#
# N and <unk> to only shares those with up on spokesman 's <eos> have plant for any compared following investors
# to a degree quantum represents the new times that have ___
#
# <unk> N says be economy day proposed he the <eos> $ with remains company equipment come own seen net than
# having just passed through one of the most profitable periods ___
#
# <unk> <eos> loan it holding in have other says a the N is maker concern has he last market bank
# pricing cycles to be sure are nothing new for plastics ___
#
# <unk> <eos> chief and six wo competition the N an a of stock $ all to in mr. he its
# and the financial decline of some looks steep only in ___
#
# and says N report <eos> <unk> world it of u.s. that their a two man traders first as when to
# we were all wonderful heroes last year says an executive ___
#
# <eos> to points the of <unk> both very president N $ in prices that a tax other is its after
# at quantum which is based in new york the trouble ___
#
# trading a black <eos> as its mr. N <unk> europe and of company the sale concern he from market says
# once known as national <unk> & chemical corp. the company ___
#
# a <unk> shareholders <eos> during to in index company which mr. the acquisition its will and of an stocks has
# mr. <unk> N years old declined to be interviewed for ___
#
# in take a remains <eos> company when many <unk> his involved oil and are its prices prime another told sell
# quantum 's lot is mostly tied to polyethylene <unk> used ___
#
# and last buy the in <unk> a u.s. chairman perhaps if when <eos> million did he marketing old that N
# in the u.s. polyethylene market quantum has claimed the largest ___
#
# and bid in that months with <eos> it a would did buy cost about <unk> such is which central based
# but its competitors including dow chemical co. union carbide corp. ___
#
# <unk> as two <eos> N of the in exchange equipment leading and mr. before bid it firms off a would
# when the price of polyethylene moves a mere penny a ___
#
# in <unk> on of <eos> N and for to ago by have a it san loss suit big part price
# in recent months the price of polyethylene even more than ___
#
# N people <unk> <eos> markets buyers do for it in which the expect small years august own their who chairman
# benchmark grades which still sold for as much as N ___
#
# <unk> and in before for <eos> that last a to gain N he more lower turn shares mr. the but
# meanwhile the price of <unk> the chemical building block of ___
#
# sales <unk> and N states <eos> says firm 's monday than to good real price in position year the would
# that <unk> <unk> quantum badly because its own plants cover ___
#
# n't current <unk> which u.s. a some take heavy company market they <eos> mr. says in N is increased the
# by many accounts an early hint of a price rout ___
#
# <unk> that the a for he is in to N <eos> and means provide it other are with been be
# china which had been putting in huge orders for polyethylene ___
#
# <unk> <eos> first last include a corp. it fell now its to rose the can in have lead this they
# <unk> that excess polyethylene would soon be <unk> around the ___
#
# and both agreement is <unk> ' <eos> union of said had market for to in company a says unit 's
# kenneth mitchell director of dow 's polyethylene business says producers ___
#
# <unk> past revenue big and put to figures <eos> first sale exchange it international according soviet lot who $ because
# they recently announced increases of a few cents a pound ___
#
# with of <eos> advertising is on the reported $ N they market was compared for in who some says mr.
# no one knows however whether the new posted prices will ___
#
# found N one would <unk> and some an high the <eos> says europe trading a based for day it he
# one <unk> is george <unk> a <unk> analyst at oppenheimer ___
#
# & <eos> of inc by being who york says is officials a into he 's with market <unk> from that
# noting others ' estimates of when price increases can be ___
#
# <unk> to would with that a also for new shares will by become the u.s. says might around corp. just
# he argues that efforts to firm up prices will be ___
#
# <eos> <unk> on to in N it made or bid the of stock-index getting for gains more said long while
# a quick turnaround is crucial to quantum because its cash ___
#
# million <eos> <unk> but in earnings week and says a rise he to the first have be according ' they
# the company is trying to carry out a three-year $ ___
#
# million billion <unk> <eos> a in the he but and they has of have for from yesterday to is as
# at the same time its annual payments on long-term debt ___
#
# N rally <unk> $ basis investors had bad in of at <eos> 's as the on than for say yesterday
# quantum described the payout at the time as a way ___
#
# auction to <unk> would of bid been in who <eos> N a profit he from agreement says that the and
# some analysts saw the payment as an effort also to ___
#
# <unk> the gain <eos> years a yesterday prices that on N and its up their higher if an is losses
# whether a cash crunch might eventually force the company to ___
#
# their <unk> <eos> to its though for the central a and lower it data family sold marks other earnings around
# some viewed his response that company directors review the dividend ___
#
# <unk> <eos> and were corp. because was exchange of in stock N a which says it since is companies to
# but others came away thinking he had given something less ___
#
# N <unk> <eos> when $ be ended cents in with go week to says he wo as million his and
# in any case on the day of the meeting quantum ___
#
# <unk> shearson april outstanding six gain subject the maker and steel that technology wall took problems cents especially day street
# on top of everything else quantum <unk> a disaster at ___
#
# and <unk> <eos> time for he the beginning 's is three several of maker point in that if years to
# after an explosion <unk> the plant in june the company ___
#
# N <unk> <eos> did to new on its mr. shareholders a was quarter largest of in from # $ an
# this human toll adds the most painful <unk> yet to ___
#
# family <eos> <unk> high it and buy if the board its he that with another one up today three so
# until this year the company had been steadily lowering its ___
#
# and the <unk> to chairman in management part mr. of were brokerage been <eos> at N nearly was currency began
# a prolonged production halt at the plant could introduce another ___
#
# <eos> N <unk> to and its a the their west in includes they working $ say buy-out go it oct.
# when a plant has just been running flat out to ___
#
# up <unk> big and 's over <eos> seven the N with only at managers of central it profit high financing
# but the numbers become <unk> and subject to <unk> between ___
#
# <eos> to los volume in <unk> not the from try and said later decline but operations involved including by n't
# you say you could have sold x percent of this ___
#
# <eos> N and deal two it to <unk> from last we major before in by spokesman that at for mr.
# quantum hopes the morris plant where limited production got under ___
#
# <unk> N made that for in than and a but to which sale at <eos> of yesterday the time commission
# the plant usually accounts for N N to N N ___
#
# <eos> but from in the a year N to and by nearly decline after mortgage on net <unk> yield six
# the plant expansion should strengthen the company 's <unk> in ___
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:29: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# <eos> and of <unk> first 's to N it car with a retail he in $ for name him but
# by lifting <unk> production the expansion will also lower the ___
#
# <unk> future is he to tax can and major <eos> for a offer quarter in have had of the 's
# quantum is also tightening its grip on its one large ___
#
# that <unk> to campaign and in would is by according ever based a as <eos> N big said talks more
# through a venture with its investment banker first boston corp. ___
#
# <unk> N is after <eos> drexel that annual $ monday 's it as in and which the to loss firms
# some analysts speculate the weakening stock may yet attract a ___
#
# <unk> <eos> N to price that it yesterday of economy in $ with and bid 's on last boston offer
# the name <unk> in rumors is british petroleum co. which ___
#
# <unk> to the that earnings looking and in <eos> division a of for firms get were on been mr. big
# asked about a bid for quantum a <unk> spokesman says ___
#
# is that <unk> N has big a have would to plan for at from while mr. paid will market and
# rjr nabisco inc. is <unk> its division responsible for buying ___
#
# <unk> need <eos> to that shares the have traders N and of general it had during some goods mr. in
# a spokesman for the new york-based food and tobacco giant ___
#
# <eos> <unk> de is and in new a came its have they but technology bought who says based the he
# the spokesman said rjr is discussing its <unk> plans with ___
#
# <unk> some national results project that N 's big is share to street acquisition but take talks taken in mr.
# we found with the size of our media purchases that ___
#
# <unk> it bank sale so N <eos> is its and the that production in he not volume off company other
# an executive close to the company said rjr is spending ___
#
# <unk> to and of who be a demand <eos> had reserve will may for was exchange in made price being
# the spokesman said the broadcast unit will be <unk> dec. ___
#
# pay <unk> year recently the things its in and they ltd. $ he 's first a adds raise that ual
# the broadcast group had been based in new york until ___
#
# <eos> <unk> N production proposed foreign chairman top company gain an two its composite a $ hard to no mr.
# one employee with the group said rjr moved N employees ___
#
# <unk> N that new earnings the its have a we for to by $ cents is german company were with
# ...
# even network executives however admit privately that victory either in ___
#
# N power of when <eos> and <unk> from markets it new next that is years to mr. results what year
# and so the networks also are pushing for new ways ___
#
# <unk> <eos> the and of ual 's from heavy in today says at on american to been thing he equipment
# that became clear last week with the disclosure that national ___
#
# <unk> would paid could in used cost has its interest will <eos> well do campaign taken was he it development
# nbc 's interest may revive the deal which mgm\/ua killed ___
#
# and been <eos> <unk> loan to a its began he of major for car an the ca by from in
# even if that deal is n't revived nbc hopes to ___
#
# <unk> <eos> and up into him 's it end N two around its which a them the on for as
# nbc may yet find a way to take a passive ___
#
# <eos> the did and of from compared <unk> a if with is in would make early at N during that
# and any nbc effort could prompt cbs inc. and abc ___
#
# <eos> N is <unk> its and other the he a to that for which have this 's as but it
# but the networks ' push may only <unk> an increasingly ___
#
# <unk> <eos> the for to its is N though and other david it a on says with are lead in
# both sides are to sit down next month for yet ___
#
# to <unk> there investors financing been <eos> months big that prices $ the business with they N had traders offering
# few people <unk> to the talks expect the studios to ___
#
# <unk> <eos> the its and as been cents $ ual it N debt on 's off or use their a
# the networks still are <unk> in their authority over what ___
#
# commercial <unk> james political individual going <eos> high steel he to pay banks mr. net this the dealers and east
# studios are <unk> to get shows in prime-time <unk> and ___
#
# <unk> <eos> city in last and new the N business free a gas two loans from national institute started to
# and that 's why the rules for the most part ___
#
# <unk> N income to and $ <eos> of the its but had are market it their some a is up
# studio executives in on the talks including officials at paramount ___
#
# & new that a <unk> has company however and with 's than some <eos> by on of would are is
# but mr. <unk> who represents the studios asserts the whole ___
#
# says and <eos> black <unk> which its chairman mr. of this ms. most for world who the with in he
# such <unk> leave network officials all the more doubtful that ___
#
# risk <unk> de the 's <eos> used paid its will one he a after off to no have able could
# they do n't seem to have an incentive to negotiate ___
#
# <unk> that what orders we mr. in name such buy-out ' with problems only $ money to the would plans
# and there 's no indication that washington is prepared to ___
#
# <unk> a 's <eos> group its an the to he in time did and as that company n't yesterday oct.
# congress has said repeatedly it wants no part of the ___
#
# <eos> put <unk> market community has things 's of is deal paid price in time to world was security futures
# but recent developments have made the networks and nbc president ___
#
# chief <eos> and N n't the to <unk> we in ual its it earnings $ have recent however no he
# the latest <unk> sony corp. 's plan to acquire columbia ___
#
# results particularly <unk> york the ual time use N future business court higher $ stock free a large people <eos>
# i wonder what walter <unk> will think of the <unk> ___
#
# and currently <unk> <eos> left says such remain spokesman its sell a mr. in association biggest their to that of
# in his article mr. <unk> who was in europe last ___
#
# <unk> <eos> the N of with and to away at because we $ after as in that going he but
# he did n't mention that nbc in the meantime was ___
#
# <unk> is <eos> and have in can business says has your he the loan would to too disclosed a had
# an nbc spokesman <unk> that mr. <unk> 's <unk> was ___
#
# <unk> too reported he 's average is that and a have took other <eos> to says little most the executive
# the big three 's <unk> for deregulation began <unk> in ___
#
# <unk> <eos> N 's london and it three financial the york quarter of in called is parts statement man under
# although time already had a long-term contract to buy movies ___
#
# <unk> the N financing a would that has debt their problems to stock in mr. scheduled and as washington first
# nbc 's mr. wright led the way in <unk> the ___
#
# <eos> he to <unk> of in was futures market up 's been and a the sales steel but could it
# he spoke up again when the sony bid for columbia ___
#
# N <eos> <unk> parent of and the three with to it that german up in a year 's he yesterday
# since nbc 's interest in the qintex bid for mgm\/ua ___
#
# <unk> he <eos> and the is N costs if of does service in chairman their be been to 's its
# with a qintex deal nbc would move into <unk> territory ___
#
# <unk> our the says see is a <eos> he market to are in both they will have but sales it
# it 's never really been tested says william <unk> iii ___
#
# <unk> its he been director a that and but is we new the price 's old says have in to
# he now runs policy communications in washington consulting to media ___
#
# <unk> such in through and a they would that with two its he <eos> only past mr. on has 's
# <unk> rules do n't <unk> block a network from buying ___
#
# the fall meet <eos> that N in <unk> to major but his and by mr. chicago old have take be
# hence nbc might be able to take say a N ___
#
# decline <eos> managers in strong with a <unk> to he N of it stake between while according mr. they futures
# if the transaction raised objections the studio 's <unk> operations ___
#
# <eos> <unk> an and it a be analysts N the rep. in recently to its enough some quickly currently he
# but such <unk> would still block the networks from <unk> ___
#
# and <eos> <unk> the it in steel old whose that black costs to we there of two he is but
# under current rules even when a network fares well with ___
#
# approval soviet that securities in <unk> prime the $ industry old N results and of banking on to says at
# instead abc will have to sell off the rights for ___
#
# <unk> delivery N to <eos> the takeover face real amount talks last their after another at show had would in
# the networks admit that the chances of getting the relief ___
#
# a <unk> private is such expected already been the he on which for that this sales meet network and to
# the <unk> federal communications commission had ruled in favor of ___
#
# <eos> in <unk> and their bank exchange market against a york nearly 's N that it the been from price
# various evidence including a <unk> institution study of some N ___
#
# year <eos> they in worth and N to a shares with down but the close point is <unk> options good
# but just eight days before the rules were to die ___
#
# <unk> <eos> a from been and the several but that its he as mr. N with because $ to at
# network officials involved in the studio talks may hope the ___
#
# was <eos> decline is market had said <unk> of if for provide large futures in 's point board ad agency
# in congress the issue <unk> it 's about money not ___
#
# <eos> have <unk> in but a to some at major about rally he had dow example the would however by
# a spokesman for rep. edward j. markey <unk> who heads ___
#
# says and new <unk> concern it of last <eos> a his is for in mr. its price chairman to market
# but he said mr. markey hopes this <unk> the networks ___
#
# <unk> and a such that in is steel last be been the says world on for we of late its
# and at the fcc meanwhile new chairman alfred c. <unk> ___
#
# <eos> have he and that it its a even to banks <unk> the for been mr. other company our are
# recognition equipment inc. said it settled a civil action filed ___
#
# have <unk> the major and america stake in but ago president old yet may life contract during for that make
# the government sued the company in april seeking $ N ___
#
# <eos> a in <unk> this share out on to at yen N from and for they its traders of drop
# the suit named the company former chief executive officer william ___
#
# trading <unk> major the with N <eos> points last in to and options made say big it this boost of
# the suit charged the defendants with causing peter e. <unk> ___
#
# and its chairman <unk> <eos> the it in chief a that last is an from got president high price N
# mr. <unk> was previously sentenced to four years in prison ___
#
# <unk> never the when <eos> as mr. congress any now insurance a they which to executives acquisition yesterday producers and
# in the agreement recognition agreed to pay the government $ ___
#
# million <unk> billion a <eos> and the face this he to might they with down be says in large at
# a trial on criminal allegations against the company and the ___
#
# <eos> <unk> of 's had is he board N group by name firms future company to and also when investment
# they were indicted last october on charges of fraud theft ___
#
# and co <eos> <unk> west he its in a N only country the information recent will from high of less
# in a related development recognition equipment said the postal service ___
#
# <eos> $ an <unk> N that price have but to in work and a without it charge its too is
# the postal service originally suspended the company oct. N N ___
#
# <eos> of he to from some a and its the tokyo was in that october bond but $ for N
# the company said it will continue to pursue a lifting ___
#
# of the <eos> <unk> who and from in by problems a if at sell take on as is with while
# intel corp. reported a N N drop in third-quarter net ___
#
# <unk> <eos> N $ he the in profit of friday was to then or mr. it were up because for
# the big semiconductor and computer maker said it had net ___
#
# earnings N and <eos> <unk> did with a in interest no loss on for of weeks mr. years $ the
# the lower net included a charge of $ N million ___
#
# $ N to a <unk> at gain for <eos> that from but which since its n't in or the it
# earning also fell from the year-ago period because of slowing ___
#
# N <eos> <unk> from to and the but is a in its took or that performance year are which for
# sales amounted to $ N million down N N from ___
#
# N <eos> <unk> year then 's its the mortgage share $ acquire previous this equity second cents contract million at
# intel 's stock rose in early over-the-counter trading friday as ___
#
# at N <eos> international as <unk> in n't mr. cents from to it those is market says the a possible
# but intel later <unk> to the stock market 's plunge ___
#
# <eos> <unk> its he of yet to mr. and the have a N good by can says yesterday prices make
# in august intel warned that third-quarter earnings might be flat ___
# <unk> <eos> such major four are to of their the much N include according by and will that who in
# on friday andrew <unk> intel president and chief executive officer ___
#
# <unk> in <eos> sold a to build the david N them after will was company leading were would on profit
# our bookings improved as the quarter <unk> and september was ___
#
# N chicago <eos> are with black <unk> in it increase could has new be before near to $ will says
# for the full quarter our bookings were higher than the ___
#
# magazine banks <unk> of for <eos> at 's the to closed N expected was that department and been year point
# for the nine-month period intel reported net of $ N ___
#
# or in and a <unk> N they that on year the <eos> its at to from of mr. 's $
# revenue amounted to $ N billion up slightly from $ ___
#
# million billion <unk> we this sale then a <eos> to or that us and the in day it but made
# after N years in prison mr. sisulu the <unk> former ___
#
# and <eos> the make of a <unk> is work in an its very when $ they that to mr. years
# at the same time six anc colleagues five of whom ___
#
# <eos> and contracts is N its <unk> have black who set mr. a banks finance management to technology from food
# and as the <unk> men returned to their homes the ___
#
# did market <eos> and price a of in <unk> is time 's to that board from said had was he
# a huge anc flag with black green and gold <unk> ___
#
# <eos> <unk> N means and to but its n't american it in have they might got new for his mr.
# at the small <unk> home of <unk> <unk> a leading ___
#
# N says <unk> is of it in would maker <eos> that with china for $ the agreement at food 's
# i am happy to see the spirit of the people ___
#
# association and been n't mr. <unk> be department says exchange daily note very enough most left ltd. remain does industries
# as the crowd outside his home shouted anc anc the ___
#
# and of <eos> was <unk> city up deal market 's many to had in says auction been offer banks union
# under the laws of the land the anc remains an ___
#
# <eos> in to will a used <unk> it could and of on is second agreement when that was says N
# but the <unk> release of the seven leaders who once ___
#
# <unk> to <eos> be the says for in of N a if that more $ were and american is them
# the government can never put the anc back into the ___
#
# <unk> board operations at <eos> is was mr. price of N which market period and but might pressure drop in
# things have gone too far for the government to stop ___
#
# <unk> <eos> as executives loan clear in mr. plc a by new with market the information that he contracts N
# there was certainly no <unk> the tide of anc <unk> ___
#
# and <eos> recent been west he mr. <unk> its the all a people an says to 's up of N
# <unk> <unk> of anc and <unk> we <unk> shook the ___
#
# is <eos> says was <unk> of last market soviet including 's we in technology that and price half off for
# and they called on the government to release nelson <unk> ___
#
# a <eos> in its he have and the of other some <unk> their that from take market state price at
# without him said mr. sisulu the <unk> of the others ___
#
# and <eos> is says expected an department which <unk> in mr. buying that N n't of a be to available
# president <unk> de <unk> released the anc men along with ___
#
# <unk> 's that a and is all some <eos> an because the from national to state $ but of been
# but pretoria may instead be creating a climate for more ___
#
# <unk> a in that is months N has fall it had said $ the first mr. would will <eos> this
# as other <unk> governments particularly poland and the soviet union ___
#
# <unk> de <eos> a N and the in to could have big treasury long on but united likely strong them
# as the days go by the south african government will ___
#
# another <eos> and used buy in n't we yesterday <unk> to additional make up heavy down important more index two
# if it does n't yield on these matters and eventually ___
#
# <unk> <eos> company its other N chairman high at a in the that of and trading richard last for it
# if it does the large number of <unk> whites who ___
#
# <unk> says that to a for firm in outstanding was get the since it just been this <eos> of $
# the newly released anc leaders also will be under enormous ___
#
# <unk> to <eos> he amount in a that and yet for is name from we future the but with parts
# the government is watching closely to see if their presence ___
#
# <unk> the any <eos> even but as he that hard in says would for to york higher be and of
# pretoria has n't forgotten why they were all sentenced to ___
#
# their <eos> <unk> a but to west the saying N out analysts traders from it on been head an for
# in addition the government is figuring that the releases could ___
#
# and <eos> so <unk> problems is a some have had even back why was given the in earnings they potential
# in order to head off any divisions mr. <unk> in ___
#
# york and <eos> the bank third <unk> is what 's make when u.s. while plants too N it cents last
# the men also will be faced with <unk> the generation ___
#
# that a <unk> and <eos> its in to is he such said was who N from on ever it new
# says peter <unk> president of the south african youth congress ___
#
# and <unk> to <eos> 's yesterday up oct. three N end off he state at sales its n't month a
# at last night 's rally they called on their <unk> ___
#
# <unk> took according N london the gains any move and traders by ever shares that u.s. banks <eos> but a
# we <unk> discipline because we know that the government is ___
#
# <unk> and in N the of to by stocks significant with likely <eos> before corp. beginning a mr. is n't
# we want to see nelson <unk> and all our <unk> ___
#
# <unk> airlines even <eos> to the national started his general and from co. were reported workers is would but according
